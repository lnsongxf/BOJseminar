# %%
# Julia version of the code for Chapter 5.2 in Herbst and Schorfheide (2015)
# Author: Takeki Sunakawa
# Mail: takeki.sunakawa@gmail.com
# Last updated: April 19, 2019 @ Cafe de Crie, Kobe-Motomachi
# April 27, 2019 @ Ueshima Coffee, Jiyugaoka Setagaya

using DelimitedFiles
using Random
using ControlSystems # not in CoCalc
using Distributions # not in CoCalc
using PDMats # not in CoCalc
using StatsBase # not in CoCalc
using Plots
using KernelDensity
include("gensys.jl")
# Out:
# new_div (generic function with 1 method)

# %%
function model_solution(para)

# Theta = [tau kappa psi1 psi2 rA piA gammaQ rho_R rho_g rho_z sigma_R sigma_g sigma_z]
    tau     = para[1]
    kappa   = para[2]
    psi1    = para[3]
    psi2    = para[4]
    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]
    rho_R   = para[8]
    rho_g   = para[9]
    rho_z   = para[10]
    sigma_R = para[11]
    sigma_g = para[12]
    sigma_z = para[13]
    bet = 1/(1+rA/400)

    # Equation indices

    eq_1   = 1  #** (2.1) on \hat{y}(t) **/
    eq_2   = 2  #** (2.1) on \hat{pi}(t) **/
    eq_3   = 3  #** (2.1) on \hat{R}(t) **/
    eq_4   = 4  #** \hat{y}(t-1) **/
    eq_5   = 5  #** \hat{g} process **/
    eq_6   = 6  #** \hat{z} process **/
    eq_7   = 7  #** \hat{y} expectational error **/
    eq_8   = 8  #** \hat{pi} expectational error **/

    # Variable indices 

    y_t    = 1
    pi_t   = 2
    R_t    = 3
    y1_t   = 4
    g_t    = 5
    z_t    = 6
    Ey_t1  = 7
    Epi_t1 = 8

    # Expectation error indices (eta) 

    ey_sh  = 1
    epi_sh = 2       

    # Shock indices (eps)

    z_sh = 1
    g_sh = 2
    R_sh = 3

    # SUMMARY

    neq  = 8
    neta = 2
    neps = 3

    # /** initialize matrices **/

    GAM0 = zeros(neq,neq)
    GAM1 = zeros(neq,neq)
       C = zeros(neq,1)        
     PSI = zeros(neq,neps)
     PPI = zeros(neq,neta)


    # =========================================================================
    #                 EQUILIBRIUM CONDITIONS: CANONICAL SYSTEM
    # =========================================================================

    # =========================================================================
    #          1. 
    # =========================================================================

    GAM0[eq_1,y_t] =  1
    GAM0[eq_1,R_t] =  1/tau
    GAM0[eq_1,g_t] = -(1-rho_g)
    GAM0[eq_1,z_t] = -rho_z/tau
    GAM0[eq_1,Ey_t1] = -1
    GAM0[eq_1,Epi_t1] = -1/tau

    # =========================================================================
    #          2. 
    # =========================================================================

    GAM0[eq_2,y_t] = -kappa;
    GAM0[eq_2,pi_t] = 1;
    GAM0[eq_2,g_t] =  kappa;
    GAM0[eq_2,Epi_t1] = -bet;

    # =========================================================================
    #          3. 
    # =========================================================================

    GAM0[eq_3,y_t] = -(1-rho_R)*psi2
    GAM0[eq_3,pi_t] = -(1-rho_R)*psi1
    GAM0[eq_3,R_t] = 1
    GAM0[eq_3,g_t] = (1-rho_R)*psi2
    GAM1[eq_3,R_t] = rho_R
    PSI[eq_3,R_sh] = 1

    # =========================================================================
    #          4. 
    # =========================================================================

    GAM0[eq_4,y1_t] = 1
    GAM1[eq_4,y_t] = 1

    # =========================================================================
    #          5. 
    # =========================================================================

    GAM0[eq_5,g_t] = 1
    GAM1[eq_5,g_t] = rho_g
    PSI[eq_5,g_sh] = 1

    # =========================================================================
    #          6. 
    # =========================================================================

    GAM0[eq_6,z_t] = 1
    GAM1[eq_6,z_t] = rho_z
    PSI[eq_6,z_sh] = 1

    # =========================================================================
    #          7. 
    # =========================================================================

    GAM0[eq_7,y_t] = 1
    GAM1[eq_7,Ey_t1] = 1
    PPI[eq_7,ey_sh] = 1

    # =========================================================================
    #          8. 
    # =========================================================================

    GAM0[eq_8,pi_t] = 1
    GAM1[eq_8,Epi_t1] = 1
    PPI[eq_8,epi_sh] = 1


    # =========================================================================
    #            QZ(generalized Schur) decomposition by GENSYS
    # =========================================================================

    T1, TC, T0, fmat, fwt, ywt, gev, eu, loose = gensys(GAM0,GAM1,C,PSI,PPI)

    return T1, T0

end
# Out:
# model_solution (generic function with 1 method)

# %%
function sysmat(T1,T0,para)

# Theta = [tau kappa psi1 psi2 rA piA gammaQ rho_R rho_g rho_z sigma_R sigma_g sigma_z]
    tau     = para[1]
    kappa   = para[2]
    psi1    = para[3]
    psi2    = para[4]
    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]
    rho_R   = para[8]
    rho_g   = para[9]
    rho_z   = para[10]
    sigma_R = para[11]
    sigma_g = para[12]
    sigma_z = para[13]
    
    eq_y = 1
    eq_pi = 2
    eq_ffr = 3

    # /** number of observation variables **/

    ny = 3

    # /** model variable indices **/

    y_t    = 1
    pi_t   = 2
    R_t    = 3
    y1_t   = 4
    g_t    = 5
    z_t    = 6
    Ey_t1  = 7
    Epi_t1 = 8

    # /** shock indices **/

    z_sh = 1
    g_sh = 2
    R_sh = 3

    # =========================================================================
    #                           TRANSITION EQUATION
    #    
    #            s(t) = Phi*s(t-1) + R*e(t)
    #            e(t) ~ iid N(0,Se)
    #  
    # =========================================================================

    nep = size(T0,2)

    Phi = T1

    R   = T0

    Se  = zeros(nep,nep)

    Se[z_sh,z_sh] = (sigma_z)^2
    Se[g_sh,g_sh] = (sigma_g)^2
    Se[R_sh,R_sh] = (sigma_R)^2

    # =========================================================================
    #                           MEASUREMENT EQUATION
    #   
    #            y(t) = a + b*s(t) + u(t) 
    #            u(t) ~ N(0,HH)
    #  
    # =========================================================================

    A           = zeros(ny,1)
    A[eq_y,1]   = gammaQ
    A[eq_pi,1]  = piA
    A[eq_ffr,1] = piA+rA+4*gammaQ

    nstate = size(Phi,2)

    B = zeros(ny,nstate)

    B[eq_y,y_t]   = 1
    B[eq_y,y1_t]  = -1 
    B[eq_y, z_t]  = 1
    B[eq_pi,pi_t] = 4
    B[eq_ffr,R_t] = 4

    H = zeros(ny,ny)
    # with measurement errors (from dsge1_me.yaml)
    H[eq_y,y_t] = (0.20*0.579923)^2
    H[eq_pi,pi_t] = (0.20*1.470832)^2
    H[eq_ffr,R_t] = (0.20*2.237937)^2
    
    return A,B,H,R,Se,Phi

end
# Out:
# sysmat (generic function with 1 method)

# %%
function nearestSPD(A)

    # symmetrize A into B
    B = (A + A')/2

    # Compute the symmetric polar factor of B. Call it H.
    # Clearly H is itself SPD.
    U,Sigma,V = svd(B)
    H = V*diagm(0=>Sigma)*V'

    # get Ahat in the above formula
    Ahat = (B+H)/2

    # ensure symmetry
    Ahat = (Ahat + Ahat')/2

    p = 1
    k = 0

    while (p != 0) 
        p = 0
        try
            R = cholesky(Ahat)
        catch
            p = 1
        end    

        if (p != 0)
            k = k + 1
            mineig = -maximum(-eigvals(Ahat))
            Ahat = Ahat + (-mineig*k^2 + eps(mineig))*Matrix(1.0I,size(A,1),size(A,1))
        end

    end

    return Ahat
end
# Out:
# nearestSPD (generic function with 1 method)

# %%
function PF_lik(A, B, H, Phi, R, S2, N, yt, x0, P0, resample)

    # housekeeping
    ne        = size(S2,1)
    ns = size(B,2)
    T         = size(yt,1)
    temp = cholesky(S2)
    sqrtS2 = R*temp.U'

    # matrix for store
    all_s_up  = zeros(T,ns,N) # resampled
    lik       = zeros(T,1)
    Neff      = zeros(T,1)

    # initialization
    temp_s = x0
    temp_P = P0
    temp = cholesky(temp_P)
    s_up = repeat(temp_s,1,N) + temp.U'*randn(ns,N)
#     d = MvNormal(PDMat(H))

    weights = ones(N,1)

    yy = zeros(3,1)

    # Rest of Steps
    for tt=1:1:T

        yy[:,1] = yt[tt,:]'

        # Propagate
        s_fore = Phi*s_up + sqrtS2*randn(ne,N)

        # Un-normalized weights (naive boostrap particle filter)
        perror = repeat(yy-A,1,N) - B*s_fore
        d = MvNormal(PDMat(H))
        density = pdf(d,perror)

        # Store results
        lik[tt,1]        = log(mean(density.*weights))
        all_s_up[tt,:,:] = s_up

        # Normalize weights
        weights = (density.*weights)./(mean(density.*weights))

        # Effective sample size
        Neff[tt,1] = (N^2)/sum(weights.^2)

        if resample == 1 && Neff[tt,1] <= N/2
            s_up = s_fore[:,sample(collect(1:N),Weights(weights[:,1]),N,replace=true)] # Resampling if ESS falls below a threshold
            weights = ones(N,1)
        else
            s_up = s_fore
        end    

    end

    return lik, all_s_up, Neff
end
# Out:
# PF_lik (generic function with 1 method)

# %%
function g(Phi,sqrtS2,old_states,shocks)

#     sigma_R = para[11]
#     sigma_g = para[12]
#     sigma_z = para[13]
    
    # =========================================================================
    #                           TRANSITION EQUATION
    #    
    #            s(t) = Phi*s(t-1) + R*e(t)
    #            e(t) ~ iid N(0,Se)
    #  
    # =========================================================================

#     nep = size(T0,2)

#     Phi = T1

#     R   = T0

#     Se  = zeros(nep,nep)

#     Se[z_sh,z_sh] = (sigma_z)^2
#     Se[g_sh,g_sh] = (sigma_g)^2
#     Se[R_sh,R_sh] = (sigma_R)^2
    
#     new_states = decr(old_states,shocks,params,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
    new_states = Phi*old_states + sqrtS2*shocks
    
    return new_states

end
# Out:
# g (generic function with 1 method)

# %%
function pdfy(para,yt,new_states,old_states)

    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]

    eq_y = 1
    eq_pi = 2
    eq_ffr = 3
    
    # /** model variable indices **/

    y_t    = 1
    pi_t   = 2
    R_t    = 3
    y1_t   = 4
    g_t    = 5
    z_t    = 6
    Ey_t1  = 7
    Epi_t1 = 8

#     H = zeros(ny,ny)
    me = zeros(3)
    # with measurement errors (from dsge1_me.yaml)
    me[eq_y] = 0.20*0.579923
    me[eq_pi] = 0.20*1.470832
    me[eq_ffr] = 0.20*2.237937
 
	temp = 0.0
    pdf1 = 1.0

	# log gdp growth
    temp = new_states[y_t] - old_states[y_t] + gammaQ + new_states[z_t]
    temp =(1.0/me[eq_y])*(yt[eq_y]-temp)
    pdf1 = pdf1*(1.0/me[eq_y])*exp(-0.5*temp*temp)

	# log inflation (annual)
    temp = 4*new_states[pi_t] + piA
    temp = (1.0/me[eq_pi])*(yt[eq_pi]-temp)
    pdf1 = pdf1*(1.0/me[eq_pi])*exp(-0.5*temp*temp)

	# log nominal rate (annual)
    temp = 4*new_states[R_t] + piA+rA+4*gammaQ
    temp = (1.0/me[eq_ffr])*(yt[eq_ffr]-temp)
    pdf1 = pdf1*(1.0/me[eq_ffr])*exp(-0.5*temp*temp)

    pdf1 = pdf1*1.0/(sqrt(2.0*pi)^3)
    
# 	global temp = 0.0
#     global pdf1 = 1.0

#     try

# 		# log gdp growth
#         global temp = new_states[y_t] - old_states[y_t] + gammaQ + new_states[z_t]
#         global temp =(1.0/me[eq_y])*(yt[eq_y]-temp)
#         global pdf1 = pdf1*(1.0/me[eq_y])*exp(-0.5*temp*temp)

# 	    # log inflation (annual)
#         global temp = 4*new_states[pi_t] + piA
#         global temp = (1.0/me[eq_pi])*(yt[eq_pi]-temp)
#         global pdf1 = pdf1*(1.0/me[eq_pi])*exp(-0.5*temp*temp)

# 	    # log nominal rate (annual)
#         global temp = 4*new_states[R_t] + piA+rA+4*gammaQ
#         global temp = (1.0/me[eq_ffr])*(yt[eq_ffr]-temp)
#         global pdf1 = pdf1*(1.0/me[eq_ffr])*exp(-0.5*temp*temp)

#     	global pdf1 = pdf1*1.0/(sqrt(2.0*pi)^3)

# 	catch

# 		global pdf1 = 1.0e-10

# 	end

    return pdf1

end
# Out:
# pdfy (generic function with 1 method)

# %%
function PF_lik2(Phi, R, S2, para, N, yt, resample)
# explicit loop for # of particles
    
    # housekeeping
    ne        = size(S2,1)
    ns = 8 #size(B,2)
    T         = size(yt,1)
    temp = cholesky(S2)
    sqrtS2 = R*temp.U'
    
    adjusted_proposal = zeros(T)
    adjusted_proposal_std = ones(T)
    adjusted_proposal_mu = zeros(T,ne)
    adjusted_proposal[104] = 1
    adjusted_proposal_std[104] = 1.2 # it does not matter much?
    adjusted_proposal_mu[104,2] = -3.0 # -2.0 works poorer

    # matrix for store
    all_s_up  = zeros(T,ns,N) # resampled
    lik       = zeros(T,1)
    Neff      = zeros(T,1)

    # initialization
#     temp_s = x0
#     temp_P = P0
#     temp = cholesky(temp_P)
#     s_up = repeat(temp_s,1,N) + temp.U'*randn(ns,N)
#     d = MvNormal(PDMat(H))
    s_up = zeros(ns,N)
    s_fore = zeros(ns,N)

#     for i=1:ns
#         s_up[i,:] = zeros(1,N)
#     end

    shocks = randn(ne,N)
    for j=2:N
        s_up[:,j] = g(Phi,sqrtS2,s_up[:,j-1],shocks[:,j]) #g(m,old_local.particles[:,j-1],shocks[:,j],params)
    end

    shocks = randn(ne,N)
    for j=1:N
        s_fore[:,j] = g(Phi,sqrtS2,s_up[:,j],shocks[:,j]) #g(m,old_local.particles[:,j],shocks[:,j],params)
    end

    s_up = s_fore

    density = ones(N,1)
    weights = ones(N,1)

    yy = zeros(3,1)

    # Rest of Steps
    for tt=1:1:T

        yy[:,1] = yt[tt,:]'
        shocks = randn(ne,N)

        if (adjusted_proposal[tt]==1)
            
            is_sampling_std = adjusted_proposal_std[tt]
            is_sampling_mu = adjusted_proposal_mu[tt,:]
            
#             println(size(is_sampling_std*shocks))
#             println(size(repeat(is_sampling_mu',N)))
            shocks = is_sampling_std*shocks + repeat(is_sampling_mu',N)'
            
        end
                    
        for i=1:N
        
            # Propagate
            s_fore[:,i] = g(Phi,sqrtS2,s_up[:,i],shocks[:,i])
#             s_fore[:,i] = Phi*s_up[:,i] + sqrtS2*randn(ne,1)

            # Un-normalized weights (naive boostrap particle filter)
#             perror = repeat(yy-A,1,N) - B*s_fore
#             perror = yy - A - B*s_fore[:,i]
#             d = MvNormal(PDMat(H))
#             temp = pdf(d,perror)
            # slow?
            temp = pdfy(para,yy,s_fore[:,i],s_up[:,i])
            density[i] = temp[1]

            # Store results
            all_s_up[tt,:,i] = s_up[:,i]
            
        end

        if (adjusted_proposal[tt]==1)
            
            for i=1:N

                kap = is_sampling_std^ne * exp(-0.5*shocks[:,i]'*shocks[:,i]) / exp(-0.5*(shocks[:,i].-is_sampling_mu)'*(shocks[:,i].-is_sampling_mu))
                density[i] = density[i]*kap
                
            end
            
        end        
        
        lik[tt,1]        = log(mean(density.*weights))
        
        # Normalize weights
        weights = (density.*weights)./(mean(density.*weights))

        # Effective sample size
        Neff[tt,1] = (N^2)/sum(weights.^2)

        if resample == 1 && Neff[tt,1] <= N/2
            s_up = s_fore[:,sample(collect(1:N),Weights(weights[:,1]),N,replace=true)] # Resampling if ESS falls below a threshold
            weights = ones(N,1)
        else
            s_up = s_fore
        end    

    end

    return lik, all_s_up, Neff
end
# Out:
# PF_lik2 (generic function with 1 method)

# %%
function KF(A,B,H,R,Se,Phi,y)
    
    # Initialize the State Vector at the Stationary Distribution
    T,l    = size(y)
    n,n    = size(Phi)
    s        = zeros(T+1,n)
    P        = zeros(T+1,n,n)
    s[1,:]   = zeros(n,1)'

    a = inv(Matrix(1.0I,n*n,n*n) - kron(Phi,Phi))*reshape(R*Se*R',n*n,1)
    P[1,:,:] = reshape(a,n,n)

    # Kalman Filter Recursion
    sprime             = zeros(n,1)
    Pprime             = zeros(n,n)
    errorprediction    = ones(T,l)
    Varerrorprediction = ones(T,l,l)
    liki               = ones(T,1)
    measurepredi       = ones(T,l)

    for i=1:T

        # Updating Step

        sprime = Phi*s[i,:]
        Pprime = Phi*P[i,:,:]*Phi' + R*Se*R'

        # Prediction Step

        yprediction = A + B*sprime

        v = y[i,:] - yprediction

        F = B*Pprime*B' + H

        kgain    = Pprime*B'*inv(F)
        s[i+1,:] = (sprime + kgain*v)'
        P[i+1,:,:] = Pprime - kgain*B*Pprime
        errorprediction[i,:] = v'
        Varerrorprediction[i,:,:] = F
        temp = 0.5*v'*inv(F)*v
        liki[i] = -0.5*l*log(2*pi) - 0.5*log(det(F)) - temp[1]
        measurepredi[i,:] = y[i,:]-v
    
    end


    statepredi = s
    varstatepredi = P

    return liki,measurepredi,statepredi,varstatepredi
end
# Out:
# KF (generic function with 1 method)

# %%
# main
yt = readdlm("us_extended.txt")
# m = Model(2.09,0.98,2.25,0.65,0.34,3.16,0.51,0.81,0.98,0.93,0.19,0.65,0.24)
para = [2.09,0.98,2.25,0.65,0.34,3.16,0.51,0.81,0.98,0.93,0.19,0.65,0.24]
T1,T0 = model_solution(para)
A,B,H,R,S2,Phi = sysmat(T1,T0,para)

@time liki, measurepredi, statepredi, varstatepredi = KF(A,B,H,R,S2,Phi,yt);
# Out:
#   1.150574 seconds (2.42 M allocations: 117.865 MiB, 4.97% gc time)

# %%
rng = MersenneTwister(1234)

# ns = size(B,2)
# x0 = zeros(ns)
# P0 = nearestSPD(dlyap(Phi,R*S2*R')) # to make it positive semidefinite

N = 40000 # number of particles 
# @time lik, all_s_up, Neff = PF_lik(A, B, H, Phi, R, S2, N, yt, x0, P0, 1)
@time lik, all_s_up, Neff = PF_lik2(Phi, R, S2, para, N, yt, 1);
# Out:
#  12.632453 seconds (55.53 M allocations: 8.192 GiB, 15.10% gc time)

# %%
plot(liki)
plot!(lik)

# %%
T = 145

rA      = para[5]
piA     = para[6]
gammaQ  = para[7]
rstar = gammaQ+piA/4+rA/4    

y1 = [mean(all_s_up[:,5,:],dims=2), statepredi[1:end-1,5]]
y2 = [mean(all_s_up[:,6,:],dims=2), statepredi[1:end-1,6]]
y3 = [mean(all_s_up[:,3,:],dims=2), statepredi[1:end-1,3], [0; yt[1:end-1,3]]/4 .- rstar]
plot(
    plot([1:T],y1),
    plot([1:T],y2),
    plot([1:T],y3),
    layout=(3,1),size=(800,600),legend=false
)

# %%
println(N)
plot(Neff,legend=false)
# Out:
# 40000

# %%
liki, measurepredi, statepredi, varstatepredi = KF(A,B,H,R,S2,Phi,yt)

N_opts = [50, 100, 1000]
# N_opts = [40000]

Nrep = 100

lik_store = zeros(Nrep, size(N_opts)[1])

for r = 1:Nrep
    
    for n = 1:size(N_opts)[1]
        
        N = N_opts[n]
        
        @time lik, all_s_up, Neff = PF_lik2(Phi, R, S2, para, N, yt, 1)
        
        lik_store[r,n] = sum(lik) - sum(liki)
        
    end
    
end
# Out:
#   0.013783 seconds (68.08 k allocations: 10.271 MiB)
#   0.058786 seconds (134.41 k allocations: 20.853 MiB, 24.42% gc time)
#   0.284131 seconds (1.32 M allocations: 206.427 MiB, 10.98% gc time)
#   0.012243 seconds (68.08 k allocations: 10.271 MiB, 21.48% gc time)
#   0.019389 seconds (134.41 k allocations: 20.853 MiB, 10.47% gc time)
#   0.273590 seconds (1.32 M allocations: 206.427 MiB, 9.62% gc time)
#   0.009453 seconds (68.08 k allocations: 10.271 MiB, 20.09% gc time)
#   0.019228 seconds (134.41 k allocations: 20.853 MiB, 11.24% gc time)
#   0.238481 seconds (1.32 M allocations: 206.427 MiB, 9.43% gc time)
#   0.026754 seconds (68.08 k allocations: 10.271 MiB, 17.90% gc time)
#   0.040018 seconds (134.41 k allocations: 20.853 MiB, 9.12% gc time)
#   0.505904 seconds (1.32 M allocations: 206.427 MiB, 51.37% gc time)
#   0.007793 seconds (68.08 k allocations: 10.271 MiB)
#   0.022600 seconds (134.41 k allocations: 20.853 MiB, 8.06% gc time)
#   0.241103 seconds (1.32 M allocations: 206.427 MiB, 10.90% gc time)
#   0.011132 seconds (68.08 k allocations: 10.271 MiB)
#   0.024870 seconds (134.41 k allocations: 20.853 MiB, 9.87% gc time)
#   0.207373 seconds (1.32 M allocations: 206.427 MiB, 9.74% gc time)
#   0.007768 seconds (67.75 k allocations: 10.054 MiB, 21.95% gc time)
#   0.018114 seconds (134.41 k allocations: 20.853 MiB, 11.84% gc time)
#   0.212715 seconds (1.32 M allocations: 206.427 MiB, 9.15% gc time)
#   0.013516 seconds (68.08 k allocations: 10.271 MiB, 17.78% gc time)
#   0.013707 seconds (134.41 k allocations: 20.853 MiB, 12.19% gc time)
#   0.131092 seconds (1.32 M allocations: 206.427 MiB, 11.25% gc time)
#   0.009458 seconds (68.08 k allocations: 10.271 MiB, 19.48% gc time)
#   0.019922 seconds (134.41 k allocations: 20.853 MiB, 12.37% gc time)
#   0.368431 seconds (1.32 M allocations: 206.427 MiB, 42.81% gc time)
#   0.012330 seconds (68.08 k allocations: 10.271 MiB)
#   0.024800 seconds (134.41 k allocations: 20.853 MiB, 9.57% gc time)
#   0.175644 seconds (1.32 M allocations: 206.427 MiB, 11.18% gc time)
#   0.006163 seconds (68.08 k allocations: 10.271 MiB)
#   0.013328 seconds (134.41 k allocations: 20.853 MiB, 12.37% gc time)
#   0.242100 seconds (1.32 M allocations: 206.427 MiB, 9.09% gc time)
#   0.012230 seconds (68.08 k allocations: 10.271 MiB, 18.25% gc time)
#   0.036997 seconds (134.41 k allocations: 20.853 MiB, 9.31% gc time)
#   0.319417 seconds (1.32 M allocations: 206.427 MiB, 8.66% gc time)
#   0.008988 seconds (67.75 k allocations: 10.054 MiB, 22.12% gc time)
#   0.019964 seconds (134.41 k allocations: 20.853 MiB, 9.65% gc time)
#   0.188652 seconds (1.32 M allocations: 206.427 MiB, 9.33% gc time)
#   0.020137 seconds (67.75 k allocations: 10.054 MiB, 17.09% gc time)
#   0.037497 seconds (134.41 k allocations: 20.853 MiB, 9.10% gc time)
#   0.391958 seconds (1.32 M allocations: 206.427 MiB, 42.12% gc time)
#   0.008463 seconds (68.08 k allocations: 10.271 MiB)
#   0.034670 seconds (134.41 k allocations: 20.853 MiB, 9.17% gc time)
#   0.286438 seconds (1.32 M allocations: 206.427 MiB, 9.80% gc time)
#   0.009782 seconds (68.08 k allocations: 10.271 MiB)
#   0.021879 seconds (134.41 k allocations: 20.853 MiB, 10.67% gc time)
#   0.282655 seconds (1.32 M allocations: 206.427 MiB, 8.78% gc time)
#   0.014516 seconds (67.75 k allocations: 10.054 MiB, 22.30% gc time)
#   0.023467 seconds (133.91 k allocations: 20.301 MiB, 10.34% gc time)
#   0.454408 seconds (1.32 M allocations: 206.427 MiB, 7.40% gc time)
#   0.015243 seconds (68.08 k allocations: 10.271 MiB, 12.77% gc time)
#   0.018057 seconds (134.41 k allocations: 20.853 MiB, 11.50% gc time)
#   0.237416 seconds (1.32 M allocations: 206.427 MiB, 9.11% gc time)
#   0.012467 seconds (68.08 k allocations: 10.271 MiB, 17.45% gc time)
#   0.019756 seconds (134.41 k allocations: 20.853 MiB)
#   0.324951 seconds (1.32 M allocations: 206.427 MiB, 46.62% gc time)
#   0.007748 seconds (68.08 k allocations: 10.271 MiB)
#   0.017059 seconds (134.41 k allocations: 20.853 MiB, 12.86% gc time)
#   0.233245 seconds (1.32 M allocations: 206.427 MiB, 9.29% gc time)
#   0.011320 seconds (67.75 k allocations: 10.054 MiB, 20.25% gc time)
#   0.020803 seconds (134.41 k allocations: 20.853 MiB, 10.27% gc time)
#   0.268921 seconds (1.32 M allocations: 206.427 MiB, 8.56% gc time)
#   0.014628 seconds (68.08 k allocations: 10.271 MiB, 19.31% gc time)
#   0.025230 seconds (134.41 k allocations: 20.853 MiB, 10.20% gc time)
#   0.226372 seconds (1.32 M allocations: 206.427 MiB, 8.94% gc time)
#   0.022517 seconds (68.08 k allocations: 10.271 MiB, 17.99% gc time)
#   0.035787 seconds (134.41 k allocations: 20.853 MiB, 9.38% gc time)
#   0.232189 seconds (1.32 M allocations: 206.427 MiB, 8.85% gc time)
#   0.018579 seconds (68.08 k allocations: 10.271 MiB)
#   0.037400 seconds (134.41 k allocations: 20.853 MiB, 10.59% gc time)
#   0.357459 seconds (1.32 M allocations: 206.427 MiB, 43.13% gc time)
#   0.008719 seconds (67.75 k allocations: 10.054 MiB)
#   0.016601 seconds (134.41 k allocations: 20.853 MiB, 11.20% gc time)
#   0.175964 seconds (1.32 M allocations: 206.427 MiB, 8.63% gc time)
#   0.008413 seconds (68.08 k allocations: 10.271 MiB, 21.04% gc time)
#   0.018102 seconds (134.41 k allocations: 20.853 MiB, 8.59% gc time)
#   0.249436 seconds (1.32 M allocations: 206.427 MiB, 9.33% gc time)
#   0.021713 seconds (68.08 k allocations: 10.271 MiB, 15.68% gc time)
#   0.026095 seconds (134.41 k allocations: 20.853 MiB, 9.11% gc time)
#   0.230020 seconds (1.32 M allocations: 206.427 MiB, 9.14% gc time)
#   0.015267 seconds (68.08 k allocations: 10.271 MiB, 16.56% gc time)
#   0.024985 seconds (134.41 k allocations: 20.853 MiB, 10.03% gc time)
#   0.187285 seconds (1.32 M allocations: 206.427 MiB, 10.20% gc time)
#   0.006678 seconds (68.08 k allocations: 10.271 MiB)
#   0.025545 seconds (134.41 k allocations: 20.853 MiB, 8.13% gc time)
#   0.416724 seconds (1.32 M allocations: 206.427 MiB, 43.53% gc time)
#   0.009352 seconds (68.08 k allocations: 10.271 MiB)
#   0.039100 seconds (134.41 k allocations: 20.853 MiB, 8.78% gc time)
#   0.280561 seconds (1.32 M allocations: 206.427 MiB, 9.14% gc time)
#   0.011906 seconds (68.08 k allocations: 10.271 MiB, 17.62% gc time)
#   0.022013 seconds (134.41 k allocations: 20.853 MiB, 11.55% gc time)
#   0.191275 seconds (1.32 M allocations: 206.427 MiB, 9.31% gc time)
#   0.020410 seconds (68.08 k allocations: 10.271 MiB, 16.76% gc time)
#   0.030960 seconds (134.41 k allocations: 20.853 MiB, 7.70% gc time)
#   0.254994 seconds (1.32 M allocations: 206.427 MiB, 8.89% gc time)
#   0.013386 seconds (68.08 k allocations: 10.271 MiB, 17.83% gc time)
#   0.028700 seconds (134.41 k allocations: 20.853 MiB, 11.83% gc time)
#   0.268630 seconds (1.32 M allocations: 206.427 MiB, 8.87% gc time)
#   0.016048 seconds (68.08 k allocations: 10.271 MiB)
#   0.034584 seconds (134.41 k allocations: 20.853 MiB, 9.73% gc time)
#   0.456304 seconds (1.32 M allocations: 206.427 MiB, 45.84% gc time)
#   0.015368 seconds (68.08 k allocations: 10.271 MiB)
#   0.024152 seconds (134.41 k allocations: 20.853 MiB, 9.84% gc time)
#   0.202225 seconds (1.32 M allocations: 206.427 MiB, 9.71% gc time)
#   0.009825 seconds (68.08 k allocations: 10.271 MiB, 20.26% gc time)
#   0.017877 seconds (134.41 k allocations: 20.853 MiB, 9.77% gc time)
#   0.171861 seconds (1.32 M allocations: 206.427 MiB, 9.87% gc time)
#   0.010469 seconds (68.08 k allocations: 10.271 MiB, 18.07% gc time)
#   0.015492 seconds (134.41 k allocations: 20.853 MiB, 12.20% gc time)
#   0.304199 seconds (1.32 M allocations: 206.427 MiB, 8.49% gc time)
#   0.012641 seconds (68.08 k allocations: 10.271 MiB, 18.38% gc time)
#   0.022126 seconds (134.41 k allocations: 20.853 MiB, 10.15% gc time)
#   0.181576 seconds (1.32 M allocations: 206.427 MiB, 9.01% gc time)
#   0.008017 seconds (68.08 k allocations: 10.271 MiB)
#   0.016858 seconds (134.41 k allocations: 20.853 MiB, 8.71% gc time)
#   0.508799 seconds (1.32 M allocations: 206.427 MiB, 39.25% gc time)
#   0.020108 seconds (68.08 k allocations: 10.271 MiB)
#   0.039017 seconds (134.41 k allocations: 20.853 MiB, 9.02% gc time)
#   0.225471 seconds (1.32 M allocations: 206.427 MiB, 8.79% gc time)
#   0.008323 seconds (68.08 k allocations: 10.271 MiB, 21.33% gc time)
#   0.014577 seconds (134.41 k allocations: 20.853 MiB, 11.69% gc time)
#   0.245388 seconds (1.32 M allocations: 206.427 MiB, 9.30% gc time)
#   0.013610 seconds (68.08 k allocations: 10.271 MiB, 17.33% gc time)
#   0.023043 seconds (134.41 k allocations: 20.853 MiB, 10.33% gc time)
#   0.268484 seconds (1.32 M allocations: 206.427 MiB, 8.70% gc time)
#   0.014303 seconds (68.08 k allocations: 10.271 MiB, 17.42% gc time)
#   0.024938 seconds (134.41 k allocations: 20.853 MiB, 9.85% gc time)
#   0.248732 seconds (1.32 M allocations: 206.427 MiB, 10.74% gc time)
#   0.007040 seconds (68.08 k allocations: 10.271 MiB)
#   0.016666 seconds (134.41 k allocations: 20.853 MiB, 10.06% gc time)
#   0.372449 seconds (1.32 M allocations: 206.427 MiB, 42.46% gc time)
#   0.016954 seconds (68.08 k allocations: 10.271 MiB)
#   0.032734 seconds (134.41 k allocations: 20.853 MiB, 9.50% gc time)
#   0.309891 seconds (1.32 M allocations: 206.427 MiB, 9.04% gc time)
#   0.017628 seconds (68.08 k allocations: 10.271 MiB, 17.10% gc time)
#   0.031893 seconds (134.41 k allocations: 20.853 MiB, 9.27% gc time)
#   0.370774 seconds (1.32 M allocations: 206.427 MiB, 8.19% gc time)
#   0.027819 seconds (68.08 k allocations: 10.271 MiB, 13.75% gc time)
#   0.040311 seconds (134.41 k allocations: 20.853 MiB, 9.10% gc time)
#   0.380875 seconds (1.32 M allocations: 206.427 MiB, 8.95% gc time)
#   0.026923 seconds (68.08 k allocations: 10.271 MiB, 15.83% gc time)
#   0.038130 seconds (134.41 k allocations: 20.853 MiB, 9.05% gc time)
#   0.204444 seconds (1.32 M allocations: 206.427 MiB, 9.43% gc time)
#   0.006799 seconds (68.08 k allocations: 10.271 MiB)
#   0.016186 seconds (134.41 k allocations: 20.853 MiB, 10.77% gc time)
#   0.360421 seconds (1.32 M allocations: 206.427 MiB, 47.03% gc time)
#   0.015830 seconds (68.08 k allocations: 10.271 MiB)
#   0.028794 seconds (134.41 k allocations: 20.853 MiB, 10.11% gc time)
#   0.175798 seconds (1.32 M allocations: 206.427 MiB, 10.29% gc time)
#   0.018196 seconds (68.08 k allocations: 10.271 MiB, 15.89% gc time)
#   0.030807 seconds (134.41 k allocations: 20.853 MiB, 11.14% gc time)
#   0.206813 seconds (1.32 M allocations: 206.427 MiB, 9.54% gc time)
#   0.013565 seconds (68.08 k allocations: 10.271 MiB, 20.33% gc time)
#   0.028732 seconds (134.41 k allocations: 20.853 MiB, 9.70% gc time)
#   0.293272 seconds (1.32 M allocations: 206.427 MiB, 8.40% gc time)
#   0.017447 seconds (67.75 k allocations: 10.054 MiB, 18.60% gc time)
#   0.028809 seconds (134.41 k allocations: 20.853 MiB, 9.84% gc time)
#   0.285052 seconds (1.32 M allocations: 206.427 MiB, 8.60% gc time)
#   0.014619 seconds (68.08 k allocations: 10.271 MiB)
#   0.028199 seconds (134.41 k allocations: 20.853 MiB, 9.64% gc time)
#   0.362697 seconds (1.32 M allocations: 206.427 MiB, 41.69% gc time)
#   0.014818 seconds (68.08 k allocations: 10.271 MiB)
#   0.029175 seconds (134.41 k allocations: 20.853 MiB, 9.84% gc time)
#   0.276167 seconds (1.32 M allocations: 206.427 MiB, 8.51% gc time)
#   0.026446 seconds (68.08 k allocations: 10.271 MiB, 16.04% gc time)
#   0.040440 seconds (134.41 k allocations: 20.853 MiB, 9.94% gc time)
#   0.371893 seconds (1.32 M allocations: 206.427 MiB, 8.33% gc time)
#   0.021288 seconds (68.08 k allocations: 10.271 MiB, 17.59% gc time)
#   0.036748 seconds (134.41 k allocations: 20.853 MiB, 9.31% gc time)
#   0.397938 seconds (1.32 M allocations: 206.427 MiB, 8.64% gc time)
#   0.020709 seconds (68.08 k allocations: 10.271 MiB, 16.84% gc time)
#   0.037296 seconds (134.41 k allocations: 20.853 MiB, 9.20% gc time)
#   0.351384 seconds (1.32 M allocations: 206.427 MiB, 8.55% gc time)
#   0.007606 seconds (67.75 k allocations: 10.054 MiB)
#   0.036351 seconds (134.41 k allocations: 20.853 MiB, 9.34% gc time)
#   0.377996 seconds (1.32 M allocations: 206.427 MiB, 42.89% gc time)
#   0.006738 seconds (67.75 k allocations: 10.054 MiB)
#   0.016206 seconds (134.41 k allocations: 20.853 MiB, 12.38% gc time)
#   0.306411 seconds (1.32 M allocations: 206.427 MiB, 8.37% gc time)
#   0.018149 seconds (67.75 k allocations: 10.054 MiB, 20.96% gc time)
#   0.031061 seconds (134.41 k allocations: 20.853 MiB, 9.61% gc time)
#   0.222427 seconds (1.32 M allocations: 206.427 MiB, 8.99% gc time)
#   0.019200 seconds (68.08 k allocations: 10.271 MiB, 16.62% gc time)
#   0.029586 seconds (133.91 k allocations: 20.301 MiB, 9.76% gc time)
#   0.263494 seconds (1.32 M allocations: 206.427 MiB, 9.09% gc time)
#   0.009996 seconds (67.75 k allocations: 10.054 MiB, 21.81% gc time)
#   0.017782 seconds (134.41 k allocations: 20.853 MiB)
#   0.208251 seconds (1.32 M allocations: 206.427 MiB, 10.42% gc time)
#   0.005776 seconds (68.08 k allocations: 10.271 MiB)
#   0.016191 seconds (134.41 k allocations: 20.853 MiB, 12.18% gc time)
#   0.376880 seconds (1.32 M allocations: 206.427 MiB, 50.80% gc time)
#   0.023203 seconds (68.08 k allocations: 10.271 MiB, 15.40% gc time)
#   0.039852 seconds (134.41 k allocations: 20.853 MiB, 10.25% gc time)
#   0.372011 seconds (1.32 M allocations: 206.427 MiB, 8.09% gc time)
#   0.013127 seconds (68.08 k allocations: 10.271 MiB, 17.20% gc time)
#   0.023402 seconds (134.41 k allocations: 20.853 MiB, 10.33% gc time)
#   0.174448 seconds (1.32 M allocations: 206.427 MiB, 9.98% gc time)
#   0.007675 seconds (68.08 k allocations: 10.271 MiB, 21.22% gc time)
#   0.029118 seconds (134.41 k allocations: 20.853 MiB, 9.74% gc time)
#   0.266806 seconds (1.32 M allocations: 206.427 MiB, 9.48% gc time)
#   0.005945 seconds (67.75 k allocations: 10.054 MiB)
#   0.016699 seconds (134.41 k allocations: 20.853 MiB, 11.83% gc time)
#   0.246371 seconds (1.32 M allocations: 206.427 MiB, 10.02% gc time)
#   0.010168 seconds (68.08 k allocations: 10.271 MiB)
#   0.020979 seconds (134.41 k allocations: 20.853 MiB, 11.72% gc time)
#   0.476336 seconds (1.32 M allocations: 206.427 MiB, 39.96% gc time)
#   0.014841 seconds (67.75 k allocations: 10.054 MiB, 17.06% gc time)
#   0.026962 seconds (134.41 k allocations: 20.853 MiB, 9.19% gc time)
#   0.222186 seconds (1.32 M allocations: 206.427 MiB, 8.76% gc time)
#   0.008388 seconds (67.75 k allocations: 10.054 MiB, 19.89% gc time)
#   0.014389 seconds (134.41 k allocations: 20.853 MiB, 12.18% gc time)
#   0.156170 seconds (1.32 M allocations: 206.427 MiB, 10.32% gc time)
#   0.008242 seconds (68.08 k allocations: 10.271 MiB, 21.10% gc time)
#   0.017521 seconds (134.41 k allocations: 20.853 MiB, 10.72% gc time)
#   0.162380 seconds (1.32 M allocations: 206.427 MiB, 10.12% gc time)
#   0.006818 seconds (68.08 k allocations: 10.271 MiB)
#   0.016219 seconds (134.41 k allocations: 20.853 MiB, 11.25% gc time)
#   0.231101 seconds (1.32 M allocations: 206.427 MiB, 10.08% gc time)
#   0.011854 seconds (68.08 k allocations: 10.271 MiB)
#   0.040779 seconds (134.41 k allocations: 20.853 MiB, 9.11% gc time)
#   0.512459 seconds (1.32 M allocations: 206.427 MiB, 37.76% gc time)
#   0.019709 seconds (68.08 k allocations: 10.271 MiB, 19.41% gc time)
#   0.031796 seconds (134.41 k allocations: 20.853 MiB, 9.16% gc time)
#   0.205378 seconds (1.32 M allocations: 206.427 MiB, 9.55% gc time)
#   0.009434 seconds (68.08 k allocations: 10.271 MiB, 21.33% gc time)
#   0.019945 seconds (134.41 k allocations: 20.853 MiB, 14.58% gc time)
#   0.314147 seconds (1.32 M allocations: 206.427 MiB, 8.95% gc time)
#   0.026076 seconds (68.08 k allocations: 10.271 MiB, 14.51% gc time)
#   0.044316 seconds (134.41 k allocations: 20.853 MiB, 8.80% gc time)
#   0.317105 seconds (1.32 M allocations: 206.427 MiB, 8.49% gc time)
#   0.011741 seconds (68.08 k allocations: 10.271 MiB)
#   0.024193 seconds (134.41 k allocations: 20.853 MiB, 10.10% gc time)
#   0.241528 seconds (1.32 M allocations: 206.427 MiB, 9.79% gc time)
#   0.007479 seconds (68.08 k allocations: 10.271 MiB)
#   0.018277 seconds (134.41 k allocations: 20.853 MiB, 11.82% gc time)
#   0.319511 seconds (1.32 M allocations: 206.427 MiB, 46.52% gc time)
#   0.019048 seconds (67.75 k allocations: 10.054 MiB, 16.35% gc time)
#   0.031785 seconds (134.41 k allocations: 20.853 MiB, 9.43% gc time)
#   0.247262 seconds (1.32 M allocations: 206.427 MiB, 9.03% gc time)
#   0.018109 seconds (68.08 k allocations: 10.271 MiB, 16.50% gc time)
#   0.031650 seconds (134.41 k allocations: 20.853 MiB, 9.70% gc time)
#   0.244458 seconds (1.32 M allocations: 206.427 MiB, 9.02% gc time)
#   0.013319 seconds (68.08 k allocations: 10.271 MiB, 16.04% gc time)
#   0.018921 seconds (134.41 k allocations: 20.853 MiB, 12.75% gc time)
#   0.169796 seconds (1.32 M allocations: 206.427 MiB, 9.67% gc time)
#   0.007932 seconds (68.08 k allocations: 10.271 MiB)
#   0.017797 seconds (134.41 k allocations: 20.853 MiB, 11.77% gc time)
#   0.303854 seconds (1.32 M allocations: 206.427 MiB, 9.15% gc time)
#   0.011374 seconds (68.08 k allocations: 10.271 MiB)
#   0.023121 seconds (134.41 k allocations: 20.853 MiB, 9.57% gc time)
#   0.308546 seconds (1.32 M allocations: 206.427 MiB, 46.24% gc time)
#   0.010616 seconds (68.08 k allocations: 10.271 MiB, 19.98% gc time)
#   0.018153 seconds (134.41 k allocations: 20.853 MiB, 10.90% gc time)
#   0.266363 seconds (1.32 M allocations: 206.427 MiB, 10.01% gc time)
#   0.010578 seconds (68.08 k allocations: 10.271 MiB, 20.31% gc time)
#   0.019974 seconds (134.41 k allocations: 20.853 MiB, 9.23% gc time)
#   0.217262 seconds (1.32 M allocations: 206.427 MiB, 9.40% gc time)
#   0.011574 seconds (68.08 k allocations: 10.271 MiB, 19.85% gc time)
#   0.020752 seconds (134.41 k allocations: 20.853 MiB, 10.17% gc time)
#   0.269137 seconds (1.32 M allocations: 206.427 MiB, 8.76% gc time)
#   0.013634 seconds (68.08 k allocations: 10.271 MiB)
#   0.028328 seconds (134.41 k allocations: 20.853 MiB, 10.08% gc time)
#   0.282175 seconds (1.32 M allocations: 206.427 MiB, 9.68% gc time)
#   0.014426 seconds (68.08 k allocations: 10.271 MiB)
#   0.028368 seconds (134.41 k allocations: 20.853 MiB, 10.42% gc time)
#   0.574473 seconds (1.32 M allocations: 206.427 MiB, 49.44% gc time)
#   0.019353 seconds (68.08 k allocations: 10.271 MiB, 16.36% gc time)
#   0.035006 seconds (134.41 k allocations: 20.853 MiB, 8.98% gc time)
#   0.305076 seconds (1.32 M allocations: 206.427 MiB, 8.67% gc time)
#   0.013234 seconds (68.08 k allocations: 10.271 MiB, 17.59% gc time)
#   0.023963 seconds (134.41 k allocations: 20.853 MiB, 9.37% gc time)
#   0.181114 seconds (1.32 M allocations: 206.427 MiB, 9.75% gc time)
#   0.009331 seconds (68.08 k allocations: 10.271 MiB, 21.79% gc time)
#   0.034117 seconds (134.41 k allocations: 20.853 MiB, 9.18% gc time)
#   0.253494 seconds (1.32 M allocations: 206.427 MiB, 8.58% gc time)
#   0.006475 seconds (68.08 k allocations: 10.271 MiB)
#   0.017429 seconds (134.41 k allocations: 20.853 MiB, 13.45% gc time)
#   0.334597 seconds (1.32 M allocations: 206.427 MiB, 9.55% gc time)
#   0.017863 seconds (68.08 k allocations: 10.271 MiB)
#   0.023671 seconds (133.91 k allocations: 20.301 MiB, 10.14% gc time)
#   0.298730 seconds (1.32 M allocations: 206.427 MiB, 47.88% gc time)
#   0.010411 seconds (67.75 k allocations: 10.054 MiB, 18.20% gc time)
#   0.016822 seconds (134.41 k allocations: 20.853 MiB, 11.14% gc time)
#   0.157658 seconds (1.32 M allocations: 206.427 MiB, 10.19% gc time)
#   0.010368 seconds (68.08 k allocations: 10.271 MiB, 18.91% gc time)
#   0.016089 seconds (134.41 k allocations: 20.853 MiB, 9.90% gc time)
#   0.277345 seconds (1.32 M allocations: 206.427 MiB, 8.57% gc time)
#   0.007806 seconds (68.08 k allocations: 10.271 MiB, 20.96% gc time)
#   0.021998 seconds (134.41 k allocations: 20.853 MiB)
#   0.277525 seconds (1.32 M allocations: 206.427 MiB, 9.72% gc time)
#   0.021107 seconds (68.08 k allocations: 10.271 MiB)
#   0.041505 seconds (134.41 k allocations: 20.853 MiB, 9.18% gc time)
#   0.208299 seconds (1.32 M allocations: 206.427 MiB, 9.40% gc time)
#   0.009134 seconds (68.08 k allocations: 10.271 MiB, 21.55% gc time)
#   0.028916 seconds (134.41 k allocations: 20.853 MiB, 12.71% gc time)
#   0.504390 seconds (1.32 M allocations: 206.427 MiB, 45.38% gc time)
#   0.019603 seconds (68.08 k allocations: 10.271 MiB, 16.15% gc time)
#   0.034342 seconds (134.41 k allocations: 20.853 MiB, 9.18% gc time)
#   0.283328 seconds (1.32 M allocations: 206.427 MiB, 8.72% gc time)

# %%
m = mean(lik_store,dims=1)
v = std(lik_store,dims=1)
for i = 1:3
    println([Nrep N_opts[i] m[i] v[i]])
end
# Out:
# [100.0 50.0 NaN NaN]
# [100.0 100.0 NaN NaN]
# [100.0 1000.0 -435.61 67.3769]

# %%
# kd1 = kde(lik_store[:,1])
# kd2 = kde(lik_store[:,2])
kd3 = kde(lik_store[:,3])

# plot(kd1.x,kd1.density)
# plot(kd2.x,kd2.density)
plot(kd3.x,kd3.density)
# Out:
# Bandwidth must be positive
#
# Stacktrace:
#  [1] error(::String) at .\error.jl:33
#  [2] #kde#3(::Float64, ::Type, ::Int64, ::Tuple{Float64,Float64}, ::KernelDensity.UniformWeights{100}, ::Function, ::Array{Float64,1}) at C:\Users\takeki\.julia\packages\KernelDensity\FYY3d\src\univariate.jl:155
#  [3] kde(::Array{Float64,1}) at C:\Users\takeki\.julia\packages\KernelDensity\FYY3d\src\univariate.jl:155
#  [4] top-level scope at In[19]:1
