# %%
# Julia version of the code for nonlinear filtering
# for quasi-linear models
# Author: Takeki Sunakawa
# Mail: takeki.sunakawa@gmail.com

using DelimitedFiles
using Random
using Distributions # not in CoCalc
using StatsBase # not in CoCalc
using Plots
using KernelDensity
using("linsol")

# %%
mutable struct model

    np::Int64
    ns::Int64
    nexog::Int64
    ngh::Int64
    nvars::Int64
    nv::Int64
    nz::Int64
    pctrn::Float64
    mg::Float64
    mz::Float64
    mr::Float64
    damp::Float64
    tol::Float64
    zlbflag::Bool

#     yy::Array{Float64,2}
#     T::Int64
#     me::Array{Float64,1}

    xgrid::Array{Float64,2}
    bbt::Array{Float64,2}
    bbtinv::Array{Float64,2}
    slopecon::Array{Float64,2}
    coeffcn::Array{Float64,1}
    coeffpn::Array{Float64,1}
    coeffcb::Array{Float64,1}
    coeffpb::Array{Float64,1}

    model() = new()

end

# %%
function new_model()

    m = model()
    # number of variables
    m.np = 2
    m.ns = 4
    m.nexog = 3
    m.ngh = 3
    m.nvars = m.ns+m.nexog
    m.nv = 1+m.np*m.ns
    m.nz = m.ngh^m.nexog    

    m.pctrn = 0.05*100
    m.mg = 2.0
    m.mz = 2.0
    m.mr = 2.0

    m.damp = 0.7
    m.tol = 1e-5
    m.zlbflag = 1
    
#     m.yy = readdlm("./us.txt")
#     m.T = size(m.yy)[1]
#     m.me = zeros(3)
#     m.me[1] = std(m.yy[:,1]/100)*0.2
#     m.me[2] = std(m.yy[:,2]/100)*0.2
#     m.me[3] = std(m.yy[:,3]/100)*0.2

    return m

end
# Out:
# new_model (generic function with 1 method)

# %%
function qnwnorm1(n::Int64,mu::Float64,sigma::Float64)
# Originally from Fackler and Miranda's Compecon toolbox for MATLAB
# Copyright (c) 1997-2010, Paul L. Fackler & Mario J. Miranda

# Based on an algorithm in W.H. Press, S.A. Teukolsky, W.T. Vetterling
# and B.P. Flannery, "Numerical Recipes in FORTRAN", 2nd ed.  Cambridge
# University Press, 1992.
    maxit::Int64 = 100
    pim4::Float64 = 1/pi^0.25
    m::Int64 = floor((n+1)/2)
    x = zeros(Float64,n)
    w = zeros(Float64,n)
    z::Float64 = 0.0
    for i::Int64=1:m
        # Reasonable starting values
        if (i==1)
            z = sqrt(2*n+1)-1.85575*((2*n+1)^(-1/6))
        elseif (i==2)
            z = z-1.14*(n^0.426)/z
        elseif (i==3)
            z = 1.86*z+0.86*x[1]
        elseif (i==4)
            z = 1.91*z+0.91*x[2]
        else
            z = 2*z+x[i-2]
        end
        # root finding iterations
        its::Int64 = 0
        pp::Float64 = 0
        # type for p1,p2,p3,j,z1?
        # println([its maxit])
        while (its<maxit)
            its = its+1
            p1 = pim4
            p2 = 0
            for j=1:n
                p3 = p2
                p2 = p1
                p1 = z*sqrt(2/j)*p2-sqrt((j-1)/j)*p3
            end
            pp = sqrt(2*n)*p2
            # println([its pp])
            z1 = z
            z  = z1-p1/pp
            if (abs(z-z1)<1e-14)
                break
            end
        end
        # if its>=maxit
        #    error('failure to converge in qnwnorm1')
        # end
        x[n+1-i] = z
        x[i] = -z
        w[i] = 2/(pp*pp)
        w[n+1-i] = w[i]
    end
    # println(size(x))
    w = w/sqrt(pi)
    x = x*sqrt(2)

    x = mu*ones(Float64,n) + sigma*x

    return x, w

end
# Out:
# qnwnorm1 (generic function with 1 method)

# %%
function poly2s(xx,np,ns)

    nv = 1+np*ns
    f = zeros(1,nv)
    f[1] = 1.0

    for is = 1:ns

        x = xx[is]
        f[2*is] = x
        f[2*is+1] = 2*x^2-1

    end

    return f
end
# Out:
# poly2s (generic function with 1 method)

# %%
function makegrid(np,ns)

    nv = 1+np*ns
    xgrid = zeros(nv,ns)
    x = [0 -1 1]

    iv = 2

    for is=1:ns

        for ip=1:np

            xgrid[iv,is] = x[ip+1]
            iv = iv+1

        end

    end

    return xgrid
end
# Out:
# makegrid (generic function with 1 method)

# %%
function pf(fc0n,fp0n,rnpast,znow,rnow,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
    
    invtau = 1/tau
    c0n = fc0n + invtau*(1-(1-rho_R)*psi1*bet)*fp0n - invtau*rho_R*rnpast + invtau*rho_z*znow - invtau*rnow
    c0n = c0n/(1+invtau*(1-rho_R)*(kappa*psi1+psi2))
    pi0n = kappa*c0n + bet*fp0n
    
    return c0n,pi0n
end
# Out:
# pf (generic function with 1 method)

# %%
function decr(endogvarm,shocks,para,slopecon,coeffcn,coeffpn,coeffcb,coeffpb,np,ns)

    # Theta = [tau kappa psi1 psi2 rA piA gammaQ rho_R rho_g rho_z sigma_R sigma_g sigma_z]
    invnu   = 6.0
    gyss    = 0.2
    tau     = para[1]
    kappa   = para[2]
    psi1    = para[3]
    psi2    = para[4]
    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]
    rho_R   = para[8]
    rho_g   = para[9]
    rho_z   = para[10]
    sigma_R = para[11]
    sigma_g = para[12]
    sigma_z = para[13]

#     gbar = 1/(1-gyss)
    bet  = 1/(1+rA/400)
#     piss = 1+piA/400
#     ass  = 1+gammaQ/100
#     rnss = ass*piss/bet
#     rnss = 1+gammaQ/100+piA/400+rA/400
    rstar = gammaQ+piA/4+rA/4
#     phi  = tau*(invnu-1)/piss^2/kappa # to be checked
    
    rn0 = endogvarm[1]
    gnow = endogvarm[8]
    znow = endogvarm[9]
#     gp  = rho_g*gnow + sigma_g*shocks[1]
#     zp  = rho_z*znow + sigma_z*shocks[2]
#     rp  = sigma_R*shocks[3]
    gp  = rho_g*gnow + shocks[1]
    zp  = rho_z*znow + shocks[2]
    rp  = shocks[3]

    xrn = slopecon[1,1]*rn0 + slopecon[1,2]
    xgp = slopecon[2,1]*gp + slopecon[2,2]
    xzp = slopecon[3,1]*zp + slopecon[3,2]
    xrp = slopecon[4,1]*rp + slopecon[4,2]

    # first assume the ZLB is not binding, and use coeffcn and coeffpn
    temp = poly2s([xrn xgp xzp xrp],np,ns)*coeffcn
    fc1 = temp[1]
    temp = poly2s([xrn xgp xzp xrp],np,ns)*coeffpn
    fp1 = temp[1]
    # next period's c and pi (obtained by next period's fc and fp)
    c1,pi1 = pf(fc1,fp1,rn0,zp,rp,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
    y1 = c1 + gp
    rn1 = rho_R*rn0 + (1-rho_R)*(psi1*pi1 + psi2*c1) + rp

    endogvarp = [rn1 c1 pi1 y1 rn1 fc1 fp1 gp zp rp]

    # then check if the ZLB is violated by rn1, and use coeffcb and coeffpb instead
    if (rn1<-rstar)

        temp = poly2s([xrn xgp xzp xrp],np,ns)*coeffcb
        fc1 = temp[1]
        temp = poly2s([xrn xgp xzp xrp],np,ns)*coeffpb
        fp1 = temp[1]
        # next period's c and pi (obtained by next period's fc and fp)
        if (m.zlbflag)
            c1 = fc1 - (1/tau)*(-rstar - fp1 - rho_z*zp)
            pi1 = kappa*c1 + bet*fp1
        else
            c1,pi1 = pf(fc1,fp1,rn0,zp,rp,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
        end
        y1 = c1 + gp
        rn1 = rho_R*rn0 + (1-rho_R)*(psi1*pi1 + psi2*c1) + rp

        if (m.zlbflag)
            endogvarp = [rn1 c1 pi1 y1 -rstar fc1 fp1 gp zp rp]
        else
            endogvarp = [rn1 c1 pi1 y1 rn1 fc1 fp1 gp zp rp]
        end
        
    end

    return endogvarp

end
# Out:
# decr (generic function with 1 method)

# %%
function decr2(endogvarm,para,slopecon,coeffcn,coeffpn,coeffcb,coeffpb,np,ns)

    # Theta = [tau kappa psi1 psi2 rA piA gammaQ rho_R rho_g rho_z sigma_R sigma_g sigma_z]
    invnu   = 6.0
    gyss    = 0.2
    tau     = para[1]
    kappa   = para[2]
    psi1    = para[3]
    psi2    = para[4]
    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]
    rho_R   = para[8]
    rho_g   = para[9]
    rho_z   = para[10]
    sigma_R = para[11]
    sigma_g = para[12]
    sigma_z = para[13]

#     gbar = 1/(1-gyss)
    bet  = 1/(1+rA/400)
#     piss = 1+piA/400
#     ass  = 1+gammaQ/100
#     rnss = ass*piss/bet
#     rnss = 1+gammaQ/100+piA/400+rA/400
    rstar = gammaQ+piA/4+rA/4
#     phi  = tau*(inv`nu-1)/piss^2/kappa # to be checked
    
    rnpast = endogvarm[1]
    gnow = endogvarm[8]
    znow = endogvarm[9]
    rnow = endogvarm[10]

    xrn = slopecon[1,1]*rnpast + slopecon[1,2]
    xg = slopecon[2,1]*gnow + slopecon[2,2]
    xz = slopecon[3,1]*znow + slopecon[3,2]
    xr = slopecon[4,1]*rnow + slopecon[4,2]

    # first assume the ZLB is not binding, and use coeffcn and coeffpn
    temp = poly2s([xrn xg xz xr],np,ns)*coeffcn
    fc0 = temp[1]
    temp = poly2s([xrn xg xz xr],np,ns)*coeffpn
    fp0 = temp[1]
    # next period's c and pi (obtained by next period's fc and fp)
    c0,pi0 = pf(fc0,fp0,rnpast,znow,rnow,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
    y0 = c0 + gnow
    rn0 = rho_R*rnpast + (1-rho_R)*(psi1*pi0 + psi2*c0) + rnow

    endogvarp = [rn0 c0 pi0 y0 rn0 fc0 fp0 gnow znow rnow]

    # then check if the ZLB is violated by rn1, and use coeffcb and coeffpb instead
    if (rn0<=-rstar)

        temp = poly2s([xrn xg xz xr],np,ns)*coeffcb
        fc0 = temp[1]
        temp = poly2s([xrn xg xz xr],np,ns)*coeffpb
        fp0 = temp[1]
        # next period's c and pi (obtained by next period's fc and fp)
        c0,pi0 = pf(fc0,fp0,rnpast,znow,rnow,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
#         c0 = fc0 - (1/tau)*(-rstar - fp0 - rho_z*znow)
#         pi0 = kappa*c0 + bet*fp0
        y0 = c0 + gnow
        rn0 = rho_R*rnpast + (1-rho_R)*(psi1*pi0 + psi2*c0) + rnow

#         endogvarp = [rn0 c0 pi0 y0 -rstar fc0 fp0 gnow znow rnow]
        endogvarp = [rn0 c0 pi0 y0 rn0 fc0 fp0 gnow znow rnow]

    end

    return endogvarp

end
# Out:
# decr2 (generic function with 1 method)

# %%
function solve(m,para)
    
    invnu   = 6.0
    gyss    = 0.2
    tau     = para[1]
    kappa   = para[2]
    psi1    = para[3]
    psi2    = para[4]
    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]
    rho_R   = para[8]
    rho_g   = para[9]
    rho_z   = para[10]
    sigma_R = para[11]
    sigma_g = para[12]
    sigma_z = para[13]

#     gbar = 1/(1-gyss)
    bet  = 1/(1+rA/400)
#     piss = 1+piA/400
#     ass  = 1+gammaQ/100
#     rnss = ass*piss/bet
    rstar = gammaQ+piA/4+rA/4    
#     phi  = tau*(invnu-1)/piss^2/kappa # to be checked

#     # steady state values
#     ss = steadystate(para)
#     rnss = ss[1]
#     css  = ss[2]
#     piss = ss[3]
#     yss  = ss[4]
#     rnss = ss[5]
#     fcss = ss[6]
#     fpss = ss[7]

    # set up grid points
    m.xgrid = makegrid(m.np,m.ns)
    m.bbt = zeros(m.nv,m.nv)
    for iv = 1:m.nv

        m.bbt[iv,:] = poly2s(m.xgrid[iv,:],m.np,m.ns)

    end
    m.bbtinv = inv(m.bbt)

    # set bounds
    rnmin = -m.pctrn # deviation from rstar
    rnmax = m.pctrn
    gmin = -m.mg*sigma_g/sqrt(1-rho_g^2)
    gmax = m.mg*sigma_g/sqrt(1-rho_g^2)
    zmin = -m.mz*sigma_z/sqrt(1-rho_z^2)
    zmax = m.mz*sigma_z/sqrt(1-rho_z^2)
    rmin = -m.mr*sigma_R
    rmax = m.mr*sigma_R

    m.slopecon = zeros(m.ns,2)
    m.slopecon[1,1] = 2/(rnmax-rnmin)
    m.slopecon[1,2] = -(rnmax+rnmin)/(rnmax-rnmin)
    m.slopecon[2,1] = 2/(gmax-gmin)
    m.slopecon[2,2] = -(gmax+gmin)/(gmax-gmin)
    m.slopecon[3,1] = 2/(zmax-zmin)
    m.slopecon[3,2] = -(zmax+zmin)/(zmax-zmin)
    m.slopecon[4,1] = 2/(rmax-rmin)
    m.slopecon[4,2] = -(rmax+rmin)/(rmax-rmin)

    # gh nodes and weights
    x,w = qnwnorm1(m.ngh,0.0,1.0)
    ghweights = zeros(m.nz)
    ghnodes = zeros(m.nz,m.nexog)
    for ighr = 1:m.ngh

        for ighz = 1:m.ngh

            for ighg = 1:m.ngh

                index = m.ngh^2*(ighr-1)+m.ngh*(ighz-1)+ighg
                ghweights[index] = w[ighg]*w[ighz]*w[ighr]
                ghnodes[index,:] = [x[ighg] x[ighz] x[ighr]]

            end

        end

    end


    # initial values
    # NOTE: We use an index-function approach with a pair of policy functions.
    # One assumes the ZLB always binds and the other assumes the ZLB never
    # binds. The next period's policy function is given by a weighted average
    # of the policy function in the ZLB regime and the policy function in the
    # non-ZLB regime with an indicator function. The value of the indicator
    # function is one when the notional rate is greater than the ZLB,
    # otherwise zero.
    cvec0n  = zeros(m.nv)
    pivec0n = zeros(m.nv)
    rnvec0n = zeros(m.nv)
    yvec0n  = zeros(m.nv)
    cvec0b  = zeros(m.nv)
    pivec0b = zeros(m.nv)
    rnvec0b = zeros(m.nv)
    yvec0b  = zeros(m.nv)
    cvec1n  = zeros(m.nv)
    pivec1n = zeros(m.nv)
    rnvec1n = zeros(m.nv)
    yvec1n  = zeros(m.nv)
    cvec1b  = zeros(m.nv)
    pivec1b = zeros(m.nv)
    rnvec1b = zeros(m.nv)
    yvec1b  = zeros(m.nv)

    fcvec0n = zeros(m.nv)
    fpvec0n = zeros(m.nv)
#     fcvec0b = bet*css^(-tau)/ass/piss*ones(m.nv) # assumes rn0 = 1.0
    fcvec0b = zeros(m.nv) # assumes rn0 = 1.0
    fpvec0b = zeros(m.nv)
    fcvec1n = zeros(m.nv)
    fpvec1n = zeros(m.nv)
    fcvec1b = zeros(m.nv)
    fpvec1b = zeros(m.nv)

    diff = 1e+4
    iter = 0
    global conv = true

    while ((diff>m.tol) && (iter<1000))

        # fitting polynomials
        m.coeffcn = m.bbtinv*fcvec0n
        m.coeffpn = m.bbtinv*fpvec0n
        m.coeffcb = m.bbtinv*fcvec0b
        m.coeffpb = m.bbtinv*fpvec0b

        for iv = 1:m.nv

            # variables rnot0, c0, pi0, y0, rn0, fc0, fp0, gnow, znow, rnow
            rnpast = (rnmax-rnmin)/2*m.xgrid[iv,1] + (rnmax+rnmin)/2
            gnow = (gmax-gmin)/2*m.xgrid[iv,2] + (gmax+gmin)/2
            znow = (zmax-zmin)/2*m.xgrid[iv,3] + (zmax+zmin)/2
            rnow = (rmax-rmin)/2*m.xgrid[iv,4] + (rmax+rmin)/2

            # current period's c and pi (obtained by current period's fc and fp)
            # in the non-ZLB regime
            fc0n = fcvec0n[iv]
            fp0n = fpvec0n[iv]
            c0n,pi0n = pf(fc0n,fp0n,rnpast,znow,rnow,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
            y0n = c0n + gnow
            rn0n = rho_R*rnpast + (1-rho_R)*(psi1*pi0n + psi2*c0n) + rnow            
        
            # in the ZLB regime
            fc0b = fcvec0b[iv]
            fp0b = fpvec0b[iv]
            if (m.zlbflag)
                c0b = fc0b - (1/tau)*(-rstar - fp0b - rho_z*znow)
                pi0b = kappa*c0b + bet*fp0b
            else
                c0b,pi0b = pf(fc0b,fp0b,rnpast,znow,rnow,tau,kappa,psi1,psi2,rho_R,rho_z,bet)
            end
            y0b = c0b + gnow
            rn0b = rho_R*rnpast + (1-rho_R)*(psi1*pi0b + psi2*c0b) + rnow            

            # update the expectation terms fc and fp with interpolation
            shocks = zeros(3)
            fc0n = 0.0
            fp0n = 0.0
            fc0b = 0.0
            fp0b = 0.0
            for iz = 1:m.nz

#                 gp  = rho_g*gnow + sigma_g*ghnodes[iz,1]
#                 zp  = rho_z*znow + sigma_z*ghnodes[iz,2]
#                 rp  = sigma_R*ghnodes[iz,3]
                shocks[1] = sigma_g*ghnodes[iz,1]
                shocks[2] = sigma_z*ghnodes[iz,2]
                shocks[3] = sigma_R*ghnodes[iz,3]                
 
                # in the non-ZLB regime
                endogvarn = [rn0n c0n pi0n y0n rn0n fc0n fp0n gnow znow rnow]                
#                 endogvarp = decr2(endogvarn,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
                endogvarp = decr(endogvarn,shocks,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
                c1n = endogvarp[2]
                pi1n = endogvarp[3]
                fcxn = c1n
                fpxn = pi1n

                # in the ZLB regime
                endogvarb = [rn0b c0b pi0b y0b -rstar fc0b fp0b gnow znow rnow]
#                 endogvarb = [rn0b c0b pi0b y0b rn0b fc0b fp0b gp zp rp]
#                 endogvarp = decr2(endogvarb,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
                endogvarp = decr(endogvarb,shocks,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
                c1b = endogvarp[2]
                pi1b = endogvarp[3]
                fcxb = c1b
                fpxb = pi1b

                fc0n = fc0n + ghweights[iz]*fcxn
                fp0n = fp0n + ghweights[iz]*fpxn
                fc0b = fc0b + ghweights[iz]*fcxb
                fp0b = fp0b + ghweights[iz]*fpxb

            end # for iz

            cvec1n[iv]  = c0n
            pivec1n[iv] = pi0n
            yvec1n[iv]  = y0n
            rnvec1n[iv] = rn0n
            fcvec1n[iv] = fc0n
            fpvec1n[iv] = fp0n

            cvec1b[iv]  = c0b
            pivec1b[iv] = pi0b
            yvec1b[iv]  = y0b
            rnvec1b[iv] = rn0b
            fcvec1b[iv] = fc0b
            fpvec1b[iv] = fp0b

        end # for iv

        # calculate the norm between the old and new policy functions
        diffcn = maximum(abs.(cvec1n-cvec0n))
        diffpn = maximum(abs.(pivec1n-pivec0n))
        diffrn = maximum(abs.(rnvec1n-rnvec0n))
        diffyn = maximum(abs.(yvec1n-yvec0n))
        diffn  = maximum([diffcn diffpn diffrn diffyn])

        diffcb = maximum(abs.(cvec1b-cvec0b))
        diffpb = maximum(abs.(pivec1b-pivec0b))
        diffrb = maximum(abs.(rnvec1b-rnvec0b))
        diffyb = maximum(abs.(yvec1b-yvec0b))
        diffb  = maximum([diffcb diffpb diffrb diffyb])

        diff = maximum([diffn diffb])

        # update the policy functions
        cvec0n  = m.damp*cvec0n  + (1.0-m.damp)*cvec1n
        pivec0n = m.damp*pivec0n + (1.0-m.damp)*pivec1n
        rnvec0n = m.damp*rnvec0n + (1.0-m.damp)*rnvec1n
        yvec0n  = m.damp*yvec0n  + (1.0-m.damp)*yvec1n
        fcvec0n = m.damp*fcvec0n + (1.0-m.damp)*fcvec1n
        fpvec0n = m.damp*fpvec0n + (1.0-m.damp)*fpvec1n

        cvec0b  = m.damp*cvec0b  + (1.0-m.damp)*cvec1b
        pivec0b = m.damp*pivec0b + (1.0-m.damp)*pivec1b
        rnvec0b = m.damp*rnvec0b + (1.0-m.damp)*rnvec1b
        yvec0b  = m.damp*yvec0b  + (1.0-m.damp)*yvec1b
        fcvec0b = m.damp*fcvec0b + (1.0-m.damp)*fcvec1b
        fpvec0b = m.damp*fpvec0b + (1.0-m.damp)*fpvec1b

        # counter for iterations
        iter = iter + 1

#         println([iter diffn diffb])

        if (any(isnan,[fcvec0n fpvec0n fcvec0b fpvec0b])==true)
            conv = false
        end

        if (typeof([fcvec0n fpvec0n fcvec0b fpvec0b])==Array{Complex{Float64},2})
            conv = false
        end

        if (conv==false) break end

    end # while

    if (iter>=1000) conv = false end

#     println(ghnodes)
    
    return conv
end
# Out:
# solve (generic function with 1 method)

# %%
function g(m,para,old_states,shocks)

#     sigma_R = para[11]
#     sigma_g = para[12]
#     sigma_z = para[13]
    
    # =========================================================================
    #                           TRANSITION EQUATION
    #    
    #            s(t) = Phi*s(t-1) + R*e(t)
    #            e(t) ~ iid N(0,Se)
    #  
    # =========================================================================

#     nep = size(T0,2)

#     Phi = T1

#     R   = T0

#     Se  = zeros(nep,nep)

#     Se[z_sh,z_sh] = (sigma_z)^2
#     Se[g_sh,g_sh] = (sigma_g)^2
#     Se[R_sh,R_sh] = (sigma_R)^2
    
    new_states = decr(old_states,shocks,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
#     new_states = Phi*old_states + sqrtS2*shocks
    
    return new_states

end
# Out:
# g (generic function with 1 method)

# %%
function pdfy(para,yt,new_states,old_states)

    rA      = para[5]
    piA     = para[6]
    gammaQ  = para[7]

    eq_y = 1
    eq_pi = 2
    eq_ffr = 3
    
    # /** model variable indices **/

#     endogvarn = [rn0n c0n pi0n y0n rn0n fc0n fp0n gnow znow rnow]                
    y_t    = 4
    pi_t   = 3
    R_t    = 5
#     y1_t   = 4
    g_t    = 8
    z_t    = 9
#     Ey_t1  = 7
#     Epi_t1 = 8

#     H = zeros(ny,ny)
    me = zeros(3)
    # with measurement errors (from dsge1_me.yaml)
    me[eq_y] = 0.20*0.579923
    me[eq_pi] = 0.20*1.470832
    me[eq_ffr] = 0.20*2.237937
 
	temp = 0.0
    pdf1 = 1.0

	# log gdp growth
    temp = new_states[y_t] - old_states[y_t] + gammaQ + new_states[z_t]
    temp =(1.0/me[eq_y])*(yt[eq_y]-temp)
    pdf1 = pdf1*(1.0/me[eq_y])*exp(-0.5*temp*temp)

	# log inflation (annual)
    temp = 4*new_states[pi_t] + piA
    temp = (1.0/me[eq_pi])*(yt[eq_pi]-temp)
    pdf1 = pdf1*(1.0/me[eq_pi])*exp(-0.5*temp*temp)

	# log nominal rate (annual)
    temp = 4*new_states[R_t] + piA+rA+4*gammaQ
    temp = (1.0/me[eq_ffr])*(yt[eq_ffr]-temp)
    pdf1 = pdf1*(1.0/me[eq_ffr])*exp(-0.5*temp*temp)

    pdf1 = pdf1*1.0/(sqrt(2.0*pi)^3)

    return pdf1

end
# Out:
# pdfy (generic function with 1 method)

# %%
function PF2(m, para, rng, N, yt, resample)
# explicit loop for # of particles
    adjusted = 0
    
    # housekeeping
    ne = 3 #size(S2,1)
    ns = 10 #size(B,2)
    T    = size(yt,1)
    
    adjusted_proposal = zeros(T)
    adjusted_proposal_std = ones(T)
    adjusted_proposal_mu = zeros(T,ne)
    if (adjusted==1)
        adjusted_proposal[104] = 1
        adjusted_proposal_std[104] = 1.2 # it does not matter much?
        adjusted_proposal_mu[104,2] = -3.0 # -2.0 works poorer
    end

    sigma_R = para[11]
    sigma_g = para[12]
    sigma_z = para[13]
    sqrtS2 = zeros(3,3)
    sqrtS2[1,1] = sigma_g
    sqrtS2[2,2] = sigma_z
    sqrtS2[3,3] = sigma_R
    
    # matrix for store
    all_s_up  = zeros(T,ns,N) # resampled
    lik       = zeros(T,1)
    Neff      = zeros(T,1)

    # initialization
    s_up = zeros(ns,N)
    s_fore = zeros(ns,N)

    shocks = randn(rng,ne,N)
    for j=2:N
        s_up[:,j] = g(m,para,s_up[:,j-1],sqrtS2*shocks[:,j])
    end

    shocks = randn(rng,ne,N)
    for j=1:N
        s_fore[:,j] = g(m,para,s_up[:,j],sqrtS2*shocks[:,j])
    end

    s_up = copy(s_fore)

    density = ones(N,1)
    weights = ones(N,1)

    yy = zeros(3,1)

    # Rest of Steps
    for tt=1:1:T

        yy[:,1] = yt[tt,:]'
        shocks = randn(rng,ne,N)

        if (adjusted==1 && adjusted_proposal[tt]==1)
            
            is_sampling_std = adjusted_proposal_std[tt]
            is_sampling_mu = adjusted_proposal_mu[tt,:]
            shocks = is_sampling_std*shocks + repeat(is_sampling_mu',N)'
            
        end
            
        for i=1:N
        
            # Propagate
            s_fore[:,i] = g(m,para,s_up[:,i],sqrtS2*shocks[:,i])

            # Un-normalized weights (naive boostrap particle filter)
            temp = pdfy(para,yy,s_fore[:,i],s_up[:,i])
            density[i] = temp[1]

            # Store results
            all_s_up[tt,:,i] = s_up[:,i]
            
        end

        if (adjusted==1 && adjusted_proposal[tt]==1)
            
            for i=1:N

                kap = is_sampling_std^ne * exp(-0.5*shocks[:,i]'*shocks[:,i]) / exp(-0.5*(shocks[:,i].-is_sampling_mu)'*(shocks[:,i].-is_sampling_mu))
                density[i] = density[i]*kap
                
            end
            
        end        
        
        lik[tt,1]        = log(mean(density.*weights))
        
        # Normalize weights
        weights = (density.*weights)./(mean(density.*weights))

        # Effective sample size
        Neff[tt,1] = (N^2)/sum(weights.^2)

        if resample == 1 && Neff[tt,1] <= N/2
            s_up = s_fore[:,sample(rng,collect(1:N),Weights(weights[:,1]),N,replace=true)] # Resampling if ESS falls below a threshold
            weights = ones(N,1)
        else
            s_up = copy(s_fore)
        end    

    end

    return lik, all_s_up, Neff
end
# Out:
# PF2 (generic function with 1 method)

# %%
yt = readdlm("us.txt")
# m = Model(2.09,0.98,2.25,0.65,0.34,3.16,0.51,0.81,0.98,0.93,0.19,0.65,0.24)
para = [2.09,0.98,2.25,0.65,0.34,3.16,0.51,0.81,0.98,0.93,0.19,0.65,0.24]
T1,T0 = model_solution(para)
A,B,H,R,S2,Phi = sysmat(T1,T0,para)

@time liki, measurepredi, statepredi, varstatepredi = KF(A,B,H,R,S2,Phi,yt);
# Out:
# UndefVarError: model_solution not defined
#
# Stacktrace:
#  [1] top-level scope at In[15]:4

# %%
m = new_model()
@time solve(m,para)

N = 40000 # number of particles 
@time lik, all_s_up, Neff = PF2(m, para, N, yt, 1);
# Out:
#   0.033057 seconds (412.75 k allocations: 52.019 MiB, 30.97% gc time)
# (3, 40000)
# (40000, 3)
#   8.771279 seconds (86.50 M allocations: 12.228 GiB, 25.69% gc time)

# %%
plot(liki)
plot!(lik)

# %%
T = 145

rA      = para[5]
piA     = para[6]
gammaQ  = para[7]
rstar = gammaQ+piA/4+rA/4    

#     y_t    = 4
#     pi_t   = 3
#     R_t    = 5
# #     y1_t   = 4
#     g_t    = 8
#     z_t    = 9

y1 = [mean(all_s_up[:,8,:],dims=2), statepredi[1:end-1,5]]
y2 = [mean(all_s_up[:,9,:],dims=2), statepredi[1:end-1,6]]
y3 = [mean(all_s_up[:,5,:],dims=2).+rstar, statepredi[1:end-1,3].+rstar]
plot(
    plot([1:T],y1),
    plot([1:T],y2),
    plot([1:T],y3*4),
    layout=(3,1),size=(800,600),legend=false
)

# %%
println(N)
plot(Neff,legend=false)
# Out:
# 40000

# %%
liki, measurepredi, statepredi, varstatepredi = KF(A,B,H,R,S2,Phi,yt)

N_opts = [50, 100, 1000]
# N_opts = [40000]

Nrep = 100

lik_store = zeros(Nrep, size(N_opts)[1])

for r = 1:Nrep
    
    for n = 1:size(N_opts)[1]
        
        N = N_opts[n]
        
        @time lik, all_s_up, Neff = PF_lik2(m, para, N, yt, 1)
        
        lik_store[r,n] = sum(lik) - sum(liki)
        
    end
    
end
# Out:
#   0.032077 seconds (107.27 k allocations: 15.278 MiB, 42.70% gc time)
#   0.047834 seconds (213.21 k allocations: 30.908 MiB, 27.67% gc time)
#   0.276962 seconds (2.12 M allocations: 309.218 MiB, 13.90% gc time)
#   0.010532 seconds (107.25 k allocations: 15.275 MiB)
#   0.025832 seconds (212.66 k allocations: 30.842 MiB, 19.83% gc time)
#   0.446183 seconds (2.12 M allocations: 308.826 MiB, 12.73% gc time)
#   0.012083 seconds (105.05 k allocations: 14.797 MiB, 18.52% gc time)
#   0.037041 seconds (214.37 k allocations: 31.050 MiB, 11.76% gc time)
#   0.523375 seconds (2.14 M allocations: 311.000 MiB, 43.05% gc time)
#   0.015058 seconds (106.52 k allocations: 15.186 MiB, 18.75% gc time)
#   0.024676 seconds (211.29 k allocations: 30.674 MiB, 9.63% gc time)
#   0.267499 seconds (2.12 M allocations: 309.045 MiB, 13.17% gc time)
#   0.027344 seconds (107.36 k allocations: 15.288 MiB, 14.85% gc time)
#   0.042198 seconds (208.36 k allocations: 29.761 MiB, 8.60% gc time)
#   0.470951 seconds (2.13 M allocations: 309.811 MiB, 11.15% gc time)
#   0.025805 seconds (107.15 k allocations: 15.263 MiB, 17.44% gc time)
#   0.044117 seconds (211.66 k allocations: 30.720 MiB, 8.39% gc time)
#   0.335075 seconds (2.11 M allocations: 307.558 MiB, 12.71% gc time)
#   0.013056 seconds (106.08 k allocations: 15.133 MiB, 17.90% gc time)
#   0.023820 seconds (212.12 k allocations: 30.776 MiB, 8.82% gc time)
#   0.444018 seconds (2.12 M allocations: 308.575 MiB, 42.60% gc time)
#   0.010395 seconds (106.06 k allocations: 15.129 MiB, 18.16% gc time)
#   0.023540 seconds (211.54 k allocations: 30.705 MiB, 9.32% gc time)
#   0.358358 seconds (2.13 M allocations: 309.341 MiB, 11.51% gc time)
#   0.018395 seconds (107.71 k allocations: 15.332 MiB, 17.30% gc time)
#   0.033408 seconds (211.36 k allocations: 30.683 MiB, 8.55% gc time)
#   0.260240 seconds (2.12 M allocations: 308.553 MiB, 13.19% gc time)
#   0.013215 seconds (107.59 k allocations: 15.317 MiB, 16.84% gc time)
#   0.025034 seconds (213.05 k allocations: 30.889 MiB, 10.83% gc time)
#   0.385055 seconds (2.14 M allocations: 310.604 MiB, 12.09% gc time)
#   0.018897 seconds (106.04 k allocations: 15.128 MiB, 15.62% gc time)
#   0.033964 seconds (214.23 k allocations: 31.033 MiB, 8.89% gc time)
#   0.454819 seconds (2.12 M allocations: 308.821 MiB, 35.05% gc time)
#   0.013580 seconds (106.66 k allocations: 15.204 MiB, 18.31% gc time)
#   0.025515 seconds (214.01 k allocations: 31.007 MiB, 8.62% gc time)
#   0.273488 seconds (2.13 M allocations: 309.447 MiB, 13.23% gc time)
#   0.011170 seconds (106.62 k allocations: 15.199 MiB, 17.77% gc time)
#   0.021140 seconds (212.54 k allocations: 30.826 MiB, 9.88% gc time)
#   0.311511 seconds (2.13 M allocations: 309.432 MiB, 12.19% gc time)
#   0.027488 seconds (107.00 k allocations: 15.245 MiB, 14.71% gc time)
#   0.051631 seconds (213.56 k allocations: 30.951 MiB, 7.58% gc time)
#   0.347853 seconds (2.12 M allocations: 308.074 MiB, 12.29% gc time)
#   0.011087 seconds (106.37 k allocations: 15.168 MiB, 18.79% gc time)
#   0.018305 seconds (211.20 k allocations: 30.663 MiB, 10.12% gc time)
#   0.472777 seconds (2.12 M allocations: 309.239 MiB, 41.26% gc time)
#   0.011034 seconds (107.26 k allocations: 15.276 MiB, 19.29% gc time)
#   0.023512 seconds (212.97 k allocations: 30.879 MiB, 10.52% gc time)
#   0.351636 seconds (2.12 M allocations: 308.919 MiB, 12.47% gc time)
#   0.017955 seconds (106.24 k allocations: 15.152 MiB, 16.80% gc time)
#   0.033008 seconds (213.47 k allocations: 30.940 MiB, 8.77% gc time)
#   0.255836 seconds (2.12 M allocations: 308.706 MiB, 13.39% gc time)
#   0.013056 seconds (108.02 k allocations: 15.369 MiB, 18.29% gc time)
#   0.022370 seconds (211.89 k allocations: 30.747 MiB, 9.34% gc time)
#   0.307910 seconds (2.14 M allocations: 310.754 MiB, 12.49% gc time)
#   0.015793 seconds (106.94 k allocations: 15.237 MiB, 16.18% gc time)
#   0.030050 seconds (213.85 k allocations: 30.987 MiB, 9.25% gc time)
#   0.526848 seconds (2.12 M allocations: 309.204 MiB, 36.64% gc time)
#   0.019685 seconds (106.26 k allocations: 15.154 MiB, 15.69% gc time)
#   0.033944 seconds (212.49 k allocations: 30.820 MiB, 8.21% gc time)
#   0.245271 seconds (2.14 M allocations: 310.545 MiB, 13.90% gc time)
#   0.010751 seconds (107.93 k allocations: 15.358 MiB, 18.93% gc time)
#   0.021304 seconds (214.17 k allocations: 31.026 MiB, 9.76% gc time)
#   0.279828 seconds (2.12 M allocations: 309.042 MiB, 12.79% gc time)
#   0.027763 seconds (106.86 k allocations: 15.228 MiB, 14.34% gc time)
#   0.045542 seconds (214.85 k allocations: 31.108 MiB, 8.04% gc time)
#   0.436179 seconds (2.12 M allocations: 309.216 MiB, 12.43% gc time)
#   0.013673 seconds (107.46 k allocations: 15.301 MiB, 20.09% gc time)
#   0.024374 seconds (213.10 k allocations: 30.896 MiB, 8.43% gc time)
#   0.428815 seconds (2.15 M allocations: 311.800 MiB, 37.70% gc time)
#   0.011916 seconds (107.94 k allocations: 15.359 MiB, 18.42% gc time)
#   0.024603 seconds (211.33 k allocations: 30.679 MiB, 9.92% gc time)
#   0.297683 seconds (2.14 M allocations: 311.494 MiB, 12.73% gc time)
#   0.026614 seconds (107.39 k allocations: 15.293 MiB, 14.61% gc time)
#   0.043950 seconds (212.41 k allocations: 30.811 MiB, 8.23% gc time)
#   0.306299 seconds (2.11 M allocations: 307.469 MiB, 12.74% gc time)
#   0.012702 seconds (105.52 k allocations: 15.064 MiB, 18.33% gc time)
#   0.021339 seconds (213.00 k allocations: 30.883 MiB, 9.83% gc time)
#   0.291593 seconds (2.11 M allocations: 307.366 MiB, 12.75% gc time)
#   0.015787 seconds (106.71 k allocations: 15.209 MiB, 17.83% gc time)
#   0.029754 seconds (213.11 k allocations: 30.896 MiB, 10.07% gc time)
#   0.595645 seconds (2.11 M allocations: 307.531 MiB, 45.94% gc time)
#   0.010936 seconds (106.97 k allocations: 15.240 MiB, 18.71% gc time)
#   0.022139 seconds (213.36 k allocations: 30.927 MiB, 11.35% gc time)
#   0.244009 seconds (2.13 M allocations: 310.084 MiB, 12.96% gc time)
#   0.026529 seconds (106.65 k allocations: 15.202 MiB, 15.70% gc time)
#   0.045795 seconds (212.17 k allocations: 30.781 MiB, 8.63% gc time)
#   0.344130 seconds (2.13 M allocations: 310.175 MiB, 13.13% gc time)
#   0.013169 seconds (105.98 k allocations: 15.121 MiB, 16.17% gc time)
#   0.022171 seconds (212.47 k allocations: 30.818 MiB, 10.58% gc time)
#   0.226234 seconds (2.12 M allocations: 308.818 MiB, 14.19% gc time)
#   0.011303 seconds (107.20 k allocations: 15.269 MiB, 18.65% gc time)
#   0.021077 seconds (212.46 k allocations: 30.817 MiB, 11.20% gc time)
#   0.378410 seconds (2.13 M allocations: 309.424 MiB, 41.43% gc time)
#   0.013213 seconds (105.04 k allocations: 14.796 MiB, 21.31% gc time)
#   0.022892 seconds (212.19 k allocations: 30.784 MiB, 10.82% gc time)
#   0.304573 seconds (2.12 M allocations: 309.108 MiB, 12.50% gc time)
#   0.028922 seconds (106.81 k allocations: 15.222 MiB, 13.91% gc time)
#   0.045333 seconds (208.29 k allocations: 29.754 MiB, 8.84% gc time)
#   0.294463 seconds (2.12 M allocations: 308.366 MiB, 13.31% gc time)
#   0.012411 seconds (104.94 k allocations: 14.785 MiB, 16.24% gc time)
#   0.022217 seconds (213.11 k allocations: 30.896 MiB, 12.25% gc time)
#   0.230873 seconds (2.13 M allocations: 310.244 MiB, 14.00% gc time)
#   0.011148 seconds (106.05 k allocations: 15.128 MiB, 18.45% gc time)
#   0.021649 seconds (215.26 k allocations: 31.159 MiB, 10.77% gc time)
#   0.481148 seconds (2.12 M allocations: 308.880 MiB, 37.84% gc time)
#   0.015948 seconds (104.83 k allocations: 14.771 MiB, 17.06% gc time)
#   0.030213 seconds (211.93 k allocations: 30.752 MiB, 9.40% gc time)
#   0.345833 seconds (2.13 M allocations: 310.284 MiB, 12.28% gc time)
#   0.025764 seconds (106.51 k allocations: 15.185 MiB, 15.12% gc time)
#   0.048310 seconds (208.94 k allocations: 29.832 MiB, 13.11% gc time)
#   0.438560 seconds (2.13 M allocations: 309.459 MiB, 12.16% gc time)
#   0.015404 seconds (106.11 k allocations: 15.136 MiB, 17.46% gc time)
#   0.031737 seconds (214.46 k allocations: 31.061 MiB, 8.91% gc time)
#   0.279633 seconds (2.13 M allocations: 309.726 MiB, 13.06% gc time)
#   0.021627 seconds (105.83 k allocations: 15.102 MiB, 15.96% gc time)
#   0.039844 seconds (213.13 k allocations: 30.898 MiB, 8.60% gc time)
#   0.419745 seconds (2.13 M allocations: 309.359 MiB, 36.89% gc time)
#   0.011451 seconds (106.89 k allocations: 15.232 MiB, 21.01% gc time)
#   0.021560 seconds (211.56 k allocations: 30.708 MiB, 9.15% gc time)
#   0.362137 seconds (2.13 M allocations: 310.314 MiB, 11.67% gc time)
#   0.010750 seconds (106.91 k allocations: 15.234 MiB, 18.70% gc time)
#   0.022174 seconds (211.84 k allocations: 30.741 MiB, 11.14% gc time)
#   0.296531 seconds (2.12 M allocations: 308.572 MiB, 12.88% gc time)
#   0.015767 seconds (107.16 k allocations: 15.264 MiB, 19.86% gc time)
#   0.029256 seconds (212.69 k allocations: 30.845 MiB, 10.18% gc time)
#   0.361001 seconds (2.12 M allocations: 308.878 MiB, 12.02% gc time)
#   0.031539 seconds (106.04 k allocations: 15.128 MiB, 16.37% gc time)
#   0.033345 seconds (214.58 k allocations: 31.076 MiB, 9.04% gc time)
#   0.426146 seconds (2.12 M allocations: 308.703 MiB, 38.47% gc time)
#   0.027822 seconds (104.94 k allocations: 14.784 MiB, 15.42% gc time)
#   0.060216 seconds (210.52 k allocations: 30.580 MiB, 6.77% gc time)
#   0.341190 seconds (2.12 M allocations: 308.780 MiB, 11.97% gc time)
#   0.017204 seconds (106.43 k allocations: 15.175 MiB, 16.04% gc time)
#   0.029945 seconds (212.75 k allocations: 30.853 MiB, 8.93% gc time)
#   0.293868 seconds (2.12 M allocations: 308.107 MiB, 12.46% gc time)
#   0.011297 seconds (107.20 k allocations: 15.269 MiB, 19.33% gc time)
#   0.020784 seconds (212.99 k allocations: 30.882 MiB, 10.15% gc time)
#   0.242287 seconds (2.12 M allocations: 308.197 MiB, 13.65% gc time)
#   0.024016 seconds (106.71 k allocations: 15.209 MiB, 16.11% gc time)
#   0.043043 seconds (214.85 k allocations: 31.108 MiB, 8.39% gc time)
#   0.479054 seconds (2.12 M allocations: 308.962 MiB, 45.16% gc time)
#   0.011347 seconds (106.85 k allocations: 15.226 MiB, 19.15% gc time)
#   0.022250 seconds (214.08 k allocations: 31.014 MiB, 10.58% gc time)
#   0.300122 seconds (2.12 M allocations: 309.102 MiB, 13.03% gc time)
#   0.010998 seconds (106.78 k allocations: 15.217 MiB, 18.38% gc time)
#   0.023292 seconds (213.25 k allocations: 30.914 MiB, 9.15% gc time)
#   0.374599 seconds (2.12 M allocations: 308.770 MiB, 12.08% gc time)
#   0.017381 seconds (106.59 k allocations: 15.195 MiB, 16.67% gc time)
#   0.031542 seconds (211.58 k allocations: 30.709 MiB, 9.14% gc time)
#   0.390041 seconds (2.13 M allocations: 309.287 MiB, 11.65% gc time)
#   0.028210 seconds (106.96 k allocations: 15.240 MiB, 14.26% gc time)
#   0.047677 seconds (213.03 k allocations: 30.886 MiB, 8.08% gc time)
#   0.613137 seconds (2.12 M allocations: 308.685 MiB, 39.35% gc time)
#   0.027766 seconds (106.53 k allocations: 15.187 MiB, 15.01% gc time)
#   0.046417 seconds (214.99 k allocations: 31.125 MiB, 8.37% gc time)
#   0.249192 seconds (2.12 M allocations: 308.131 MiB, 13.81% gc time)
#   0.012448 seconds (106.24 k allocations: 15.152 MiB, 17.48% gc time)
#   0.037879 seconds (213.96 k allocations: 31.000 MiB, 9.58% gc time)
#   0.302944 seconds (2.12 M allocations: 308.610 MiB, 13.10% gc time)
#   0.017412 seconds (106.49 k allocations: 15.182 MiB, 16.50% gc time)
#   0.042389 seconds (213.15 k allocations: 30.902 MiB, 8.55% gc time)
#   0.287257 seconds (2.12 M allocations: 309.089 MiB, 12.44% gc time)
#   0.024190 seconds (106.99 k allocations: 15.243 MiB, 15.74% gc time)
#   0.042806 seconds (211.98 k allocations: 30.759 MiB, 8.70% gc time)
#   0.468471 seconds (2.11 M allocations: 307.808 MiB, 38.24% gc time)
#   0.011286 seconds (106.72 k allocations: 15.210 MiB, 20.16% gc time)
#   0.023707 seconds (211.57 k allocations: 30.708 MiB, 9.64% gc time)
#   0.358521 seconds (2.13 M allocations: 310.051 MiB, 11.86% gc time)
#   0.015071 seconds (107.19 k allocations: 15.268 MiB, 17.51% gc time)
#   0.021722 seconds (213.18 k allocations: 30.905 MiB, 10.98% gc time)
#   0.242960 seconds (2.13 M allocations: 309.312 MiB, 13.23% gc time)
#   0.019743 seconds (106.87 k allocations: 15.229 MiB, 18.49% gc time)
#   0.042463 seconds (212.38 k allocations: 30.808 MiB, 8.52% gc time)
#   0.287593 seconds (2.12 M allocations: 308.434 MiB, 12.37% gc time)
#   0.015306 seconds (105.29 k allocations: 14.827 MiB, 16.72% gc time)
#   0.029370 seconds (212.98 k allocations: 30.880 MiB, 8.69% gc time)
#   0.418244 seconds (2.13 M allocations: 309.573 MiB, 38.90% gc time)
#   0.012302 seconds (107.02 k allocations: 15.247 MiB, 20.77% gc time)
#   0.024945 seconds (211.18 k allocations: 30.661 MiB, 10.33% gc time)
#   0.307426 seconds (2.13 M allocations: 310.230 MiB, 11.79% gc time)
#   0.012781 seconds (106.59 k allocations: 15.194 MiB, 17.24% gc time)
#   0.045334 seconds (213.33 k allocations: 30.923 MiB, 8.49% gc time)
#   0.310554 seconds (2.12 M allocations: 309.276 MiB, 12.76% gc time)
#   0.018898 seconds (105.00 k allocations: 14.792 MiB, 19.47% gc time)
#   0.051058 seconds (212.16 k allocations: 30.780 MiB, 8.30% gc time)
#   0.368362 seconds (2.12 M allocations: 308.380 MiB, 11.80% gc time)
#   0.017397 seconds (106.80 k allocations: 15.221 MiB, 18.48% gc time)
#   0.032336 seconds (212.57 k allocations: 30.831 MiB, 9.21% gc time)
#   0.463534 seconds (2.12 M allocations: 309.115 MiB, 36.41% gc time)
#   0.011950 seconds (107.17 k allocations: 15.266 MiB, 20.03% gc time)
#   0.025218 seconds (212.59 k allocations: 30.832 MiB, 10.65% gc time)
#   0.258816 seconds (2.12 M allocations: 308.528 MiB, 14.25% gc time)
#   0.013157 seconds (106.14 k allocations: 15.140 MiB, 18.30% gc time)
#   0.027206 seconds (212.00 k allocations: 30.761 MiB, 10.52% gc time)
#   0.394814 seconds (2.12 M allocations: 308.975 MiB, 17.16% gc time)
#   0.013087 seconds (105.32 k allocations: 14.831 MiB, 23.60% gc time)
#   0.023370 seconds (211.63 k allocations: 30.715 MiB, 10.60% gc time)
#   0.255746 seconds (2.13 M allocations: 309.800 MiB, 14.25% gc time)
#   0.011616 seconds (104.84 k allocations: 14.773 MiB, 18.61% gc time)
#   0.034166 seconds (212.17 k allocations: 30.781 MiB, 8.69% gc time)
#   0.462194 seconds (2.11 M allocations: 308.011 MiB, 38.22% gc time)
#   0.013743 seconds (106.01 k allocations: 15.124 MiB, 18.53% gc time)
#   0.043577 seconds (211.94 k allocations: 30.754 MiB, 8.81% gc time)
#   0.322042 seconds (2.12 M allocations: 308.833 MiB, 12.49% gc time)
#   0.014313 seconds (106.70 k allocations: 15.208 MiB, 20.67% gc time)
#   0.026581 seconds (211.75 k allocations: 30.731 MiB, 8.59% gc time)
#   0.276193 seconds (2.13 M allocations: 309.643 MiB, 14.27% gc time)
#   0.012340 seconds (106.59 k allocations: 15.195 MiB, 21.61% gc time)
#   0.023374 seconds (212.10 k allocations: 30.773 MiB, 12.05% gc time)
#   0.245765 seconds (2.13 M allocations: 309.726 MiB, 14.59% gc time)
#   0.011151 seconds (104.84 k allocations: 14.773 MiB, 19.20% gc time)
#   0.023299 seconds (212.24 k allocations: 30.790 MiB, 13.40% gc time)
#   0.376775 seconds (2.12 M allocations: 308.641 MiB, 41.28% gc time)
#   0.015959 seconds (107.86 k allocations: 15.350 MiB, 20.07% gc time)
#   0.023161 seconds (213.36 k allocations: 30.926 MiB, 9.26% gc time)
#   0.237502 seconds (2.12 M allocations: 308.863 MiB, 13.75% gc time)
#   0.012854 seconds (107.19 k allocations: 15.268 MiB, 16.23% gc time)
#   0.023169 seconds (211.83 k allocations: 30.740 MiB, 12.77% gc time)
#   0.337635 seconds (2.12 M allocations: 308.927 MiB, 12.57% gc time)
#   0.014177 seconds (104.97 k allocations: 14.788 MiB, 27.37% gc time)
#   0.026769 seconds (211.97 k allocations: 30.757 MiB, 9.91% gc time)
#   0.246293 seconds (2.12 M allocations: 308.193 MiB, 15.28% gc time)
#   0.013630 seconds (105.64 k allocations: 15.078 MiB, 19.07% gc time)
#   0.021519 seconds (211.93 k allocations: 30.752 MiB, 11.35% gc time)
#   0.357948 seconds (2.12 M allocations: 308.874 MiB, 40.65% gc time)
#   0.012462 seconds (106.38 k allocations: 15.169 MiB, 27.94% gc time)
#   0.023657 seconds (213.14 k allocations: 30.900 MiB, 9.98% gc time)
#   0.271339 seconds (2.13 M allocations: 309.691 MiB, 12.98% gc time)
#   0.027979 seconds (106.77 k allocations: 15.216 MiB, 14.31% gc time)
#   0.041543 seconds (214.58 k allocations: 31.076 MiB, 9.57% gc time)
#   0.255774 seconds (2.12 M allocations: 309.124 MiB, 14.63% gc time)
#   0.011477 seconds (106.25 k allocations: 15.153 MiB, 17.90% gc time)
#   0.022785 seconds (212.68 k allocations: 30.844 MiB, 8.58% gc time)
#   0.240935 seconds (2.12 M allocations: 308.123 MiB, 13.32% gc time)
#   0.013815 seconds (106.52 k allocations: 15.187 MiB, 17.99% gc time)
#   0.023451 seconds (213.51 k allocations: 30.945 MiB, 10.35% gc time)
#   0.364439 seconds (2.14 M allocations: 310.789 MiB, 40.90% gc time)
#   0.015101 seconds (106.66 k allocations: 15.204 MiB, 13.62% gc time)
#   0.060942 seconds (213.36 k allocations: 30.927 MiB, 7.55% gc time)
#   0.341345 seconds (2.13 M allocations: 309.874 MiB, 12.81% gc time)
#   0.013293 seconds (106.41 k allocations: 15.173 MiB, 22.15% gc time)
#   0.037913 seconds (211.59 k allocations: 30.711 MiB, 9.26% gc time)
#   0.267210 seconds (2.12 M allocations: 309.068 MiB, 13.09% gc time)
#   0.011882 seconds (106.31 k allocations: 15.161 MiB, 20.22% gc time)
#   0.025904 seconds (214.34 k allocations: 31.047 MiB, 10.05% gc time)
#   0.246620 seconds (2.13 M allocations: 309.596 MiB, 13.60% gc time)
#   0.011816 seconds (106.40 k allocations: 15.171 MiB, 18.78% gc time)
#   0.024768 seconds (212.59 k allocations: 30.833 MiB, 9.28% gc time)
#   0.522782 seconds (2.13 M allocations: 310.419 MiB, 41.39% gc time)
#   0.016720 seconds (105.31 k allocations: 14.830 MiB, 13.31% gc time)
#   0.025504 seconds (211.72 k allocations: 30.726 MiB, 8.38% gc time)
#   0.295600 seconds (2.12 M allocations: 308.660 MiB, 12.66% gc time)
#   0.012990 seconds (106.66 k allocations: 15.203 MiB, 18.32% gc time)
#   0.024908 seconds (208.16 k allocations: 29.737 MiB, 8.17% gc time)
#   0.330372 seconds (2.12 M allocations: 308.086 MiB, 11.79% gc time)
#   0.017649 seconds (105.10 k allocations: 14.803 MiB, 16.34% gc time)
#   0.031978 seconds (208.58 k allocations: 29.789 MiB, 9.04% gc time)
#   0.284493 seconds (2.12 M allocations: 309.262 MiB, 12.72% gc time)
#   0.014594 seconds (107.82 k allocations: 15.345 MiB, 15.85% gc time)
#   0.022848 seconds (214.01 k allocations: 31.007 MiB, 10.75% gc time)
#   0.451750 seconds (2.12 M allocations: 308.980 MiB, 39.11% gc time)
#   0.017910 seconds (106.71 k allocations: 15.209 MiB, 15.74% gc time)
#   0.033417 seconds (212.24 k allocations: 30.791 MiB, 8.73% gc time)
#   0.266915 seconds (2.13 M allocations: 309.277 MiB, 12.50% gc time)
#   0.013629 seconds (107.13 k allocations: 15.260 MiB, 19.65% gc time)
#   0.039031 seconds (212.90 k allocations: 30.871 MiB, 8.96% gc time)
#   0.388940 seconds (2.12 M allocations: 308.585 MiB, 11.74% gc time)
#   0.012883 seconds (105.78 k allocations: 15.096 MiB, 16.40% gc time)
#   0.023929 seconds (211.13 k allocations: 30.655 MiB, 9.41% gc time)
#   0.351435 seconds (2.13 M allocations: 309.559 MiB, 12.18% gc time)
#   0.010543 seconds (106.22 k allocations: 15.149 MiB, 20.53% gc time)
#   0.023914 seconds (213.00 k allocations: 30.883 MiB, 8.55% gc time)
#   0.480245 seconds (2.13 M allocations: 310.169 MiB, 41.92% gc time)
#   0.029979 seconds (106.45 k allocations: 15.177 MiB, 14.12% gc time)
#   0.051542 seconds (211.52 k allocations: 30.703 MiB, 8.21% gc time)
#   0.302554 seconds (2.12 M allocations: 308.414 MiB, 12.74% gc time)
#   0.011735 seconds (107.26 k allocations: 15.276 MiB, 17.47% gc time)
#   0.043908 seconds (214.29 k allocations: 31.040 MiB, 8.16% gc time)
#   0.373336 seconds (2.12 M allocations: 309.077 MiB, 12.10% gc time)
#   0.011055 seconds (106.77 k allocations: 15.216 MiB, 18.96% gc time)
#   0.023183 seconds (212.69 k allocations: 30.845 MiB, 9.51% gc time)
#   0.378982 seconds (2.14 M allocations: 310.501 MiB, 12.15% gc time)
#   0.012809 seconds (107.23 k allocations: 15.273 MiB, 16.02% gc time)
#   0.047580 seconds (214.22 k allocations: 31.032 MiB, 8.47% gc time)
#   0.437631 seconds (2.12 M allocations: 308.998 MiB, 35.95% gc time)
#   0.016906 seconds (106.43 k allocations: 15.175 MiB, 18.40% gc time)
#   0.035985 seconds (212.84 k allocations: 30.864 MiB, 7.32% gc time)
#   0.349402 seconds (2.12 M allocations: 308.577 MiB, 12.58% gc time)
#   0.011526 seconds (106.47 k allocations: 15.181 MiB, 18.27% gc time)
#   0.034554 seconds (212.12 k allocations: 30.776 MiB, 8.23% gc time)
#   0.363971 seconds (2.12 M allocations: 309.134 MiB, 11.79% gc time)
#   0.010097 seconds (105.00 k allocations: 14.792 MiB, 19.90% gc time)
#   0.024518 seconds (211.79 k allocations: 30.735 MiB, 8.72% gc time)
#   0.308569 seconds (2.12 M allocations: 308.775 MiB, 12.95% gc time)
#   0.013237 seconds (107.62 k allocations: 15.320 MiB, 17.20% gc time)
#   0.035497 seconds (212.12 k allocations: 30.775 MiB, 5.48% gc time)
#   0.457172 seconds (2.12 M allocations: 308.829 MiB, 34.33% gc time)
#   0.014079 seconds (107.31 k allocations: 15.282 MiB, 16.29% gc time)
#   0.045228 seconds (211.20 k allocations: 30.663 MiB, 8.57% gc time)
#   0.242604 seconds (2.12 M allocations: 308.707 MiB, 13.83% gc time)

# %%
# kd1 = kde(lik_store[:,1])
# kd2 = kde(lik_store[:,2])
kd3 = kde(lik_store[:,3])

# plot(kd1.x,kd1.density)
# plot!(kd2.x,kd2.density)
plot(kd3.x,kd3.density)

# %%
using Plots

include("linsol.jl")

T1,T0 = model_solution(para)

rA      = para[5]
piA     = para[6]
gammaQ  = para[7]
rho_R   = para[8]
rho_g   = para[9]
rho_z   = para[10]
sigma_R = para[11]
sigma_g = para[12]
sigma_z = para[13]

bet  = 1/(1+rA/400)
rstar = gammaQ+piA/4+rA/4

# set bounds
rnmin = -m.pctrn
rnmax = m.pctrn
gmin = -m.mg*sigma_g/sqrt(1-rho_g^2)
gmax = m.mg*sigma_g/sqrt(1-rho_g^2)
zmin = -m.mz*sigma_z/sqrt(1-rho_z^2)
zmax = m.mz*sigma_z/sqrt(1-rho_z^2)
rmin = -m.mr*sigma_R
rmax = m.mr*sigma_R

rngrid = collect(LinRange(rnmin,rnmax,101))
ggrid = collect(LinRange(gmin,gmax,101))
zgrid = collect(LinRange(zmin,zmax,101))
rgrid = collect(LinRange(rmin,rmax,101))

rnvec_lin = zeros(101)
pivec_lin = zeros(101)
yvec_lin  = zeros(101)
cvec_lin  = zeros(101)
rnvec_nolin = zeros(101)
pivec_nolin = zeros(101)
yvec_nolin  = zeros(101)
cvec_nolin  = zeros(101)

for i = 1:101
    
    rnpast = rngrid[i]
#     rnpast = 0
#     gnow = ggrid[i]
    gnow = 0 #gmax
#     znow = zgrid[i]
    znow = zmin
#     rnow = rgrid[i]
    rnow = rmin

    endogvarm = zeros(8)
    endogvarm[3] = rnpast
    shocks = zeros(3)
    shocks[1] = znow
    shocks[2] = gnow
    shocks[3] = rnow
    endogvar = T1*endogvarm + T0*shocks
    
    rnvec_lin[i] = endogvar[3]
    pivec_lin[i] = endogvar[2]
    yvec_lin[i] = endogvar[1]    
    
#     endogvarm = [rnpast 0 0 0 0 0 0 gnow znow rnow]
    endogvarm = [rnpast 0 0 0 0 0 0 0 0 0]
    shocks = [gnow znow rnow]
#     endogvar = decr2(endogvarm,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
    endogvar = decr(endogvarm,shocks,para,m.slopecon,m.coeffcn,m.coeffpn,m.coeffcb,m.coeffpb,m.np,m.ns)
    
    rnvec_nolin[i] = endogvar[5]
    pivec_nolin[i] = endogvar[3]
    yvec_nolin[i] = endogvar[4]
    cvec_nolin[i] = endogvar[2]
    
end

println(rstar)

plot(
#     plot(rngrid,rnvec_nolin,title="Policy Rate"),
#     plot(rngrid,pivec_nolin,title="Inflation"),
#     plot(rngrid,yvec_nolin,title="Output Gap"),
    plot(rngrid,[rnvec_nolin rnvec_lin],title="Policy Rate"),
    plot(rngrid,[pivec_nolin pivec_lin],title="Inflation"),
    plot(rngrid,[yvec_nolin yvec_lin],title="Output Gap"),
    layout=(3,1),size=(800,600),label=["nolin" "lin"]
)
# Out:
# 1.385
