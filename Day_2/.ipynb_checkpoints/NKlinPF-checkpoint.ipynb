# %%
# Julia version of the code for nonlinear filtering in Herbst and Schorfheide (2015)
# Author: Takeki Sunakawa
# Mail: takeki.sunakawa@gmail.com

using DelimitedFiles
using Random
using ControlSystems # not in CoCalc
using Distributions # not in CoCalc
using PDMats # not in CoCalc
using StatsBase # not in CoCalc
using Plots
using KernelDensity
include("linsol.jl")
# Out:
# KF (generic function with 1 method)

# %%
function nearestSPD(A)

    # symmetrize A into B
    B = (A + A')/2

    # Compute the symmetric polar factor of B. Call it H.
    # Clearly H is itself SPD.
    U,Sigma,V = svd(B)
    H = V*diagm(0=>Sigma)*V'

    # get Ahat in the above formula
    Ahat = (B+H)/2

    # ensure symmetry
    Ahat = (Ahat + Ahat')/2

    p = 1
    k = 0

    while (p != 0) 
        p = 0
        try
            R = cholesky(Ahat)
        catch
            p = 1
        end    

        if (p != 0)
            k = k + 1
            mineig = -maximum(-eigvals(Ahat))
            Ahat = Ahat + (-mineig*k^2 + eps(mineig))*Matrix(1.0I,size(A,1),size(A,1))
        end

    end

    return Ahat
end
# Out:
# nearestSPD (generic function with 1 method)

# %%
function PF(A, B, H, Phi, R, S2, N, yt, x0, P0, resample)

    # housekeeping
    ne        = size(S2,1)
    ns = size(B,2)
    T         = size(yt,1)
    temp = cholesky(S2)
    sqrtS2 = R*temp.U'
    d = MvNormal(PDMat(H))

    # matrix for store
    all_s_up  = zeros(T,ns,N) # resampled
    lik       = zeros(T,1)
    Neff      = zeros(T,1)

    # initialization
    temp_s = x0
    temp_P = P0
    temp = cholesky(temp_P)
    s_up = repeat(temp_s,1,N) + temp.U'*randn(ns,N)

    weights = ones(N,1)

    yy = zeros(3,1)

    # Rest of Steps
    for tt=1:1:T

        yy[:,1] = yt[tt,:]'

        # Propagate
        s_fore = Phi*s_up + sqrtS2*randn(ne,N)

        # Un-normalized weights (naive boostrap particle filter)
        perror = repeat(yy-A,1,N) - B*s_fore
        density = pdf(d,perror)

        # Store results
        lik[tt,1]        = log(mean(density.*weights))
        all_s_up[tt,:,:] = s_up

        # Normalize weights
        weights = (density.*weights)./(mean(density.*weights))

        # Effective sample size
        Neff[tt,1] = (N^2)/sum(weights.^2)

        if resample == 1 && Neff[tt,1] <= N/2
            s_up = s_fore[:,sample(collect(1:N),Weights(weights[:,1]),N,replace=true)] # Resampling if ESS falls below a threshold
            weights = ones(N,1)
        else
            s_up = copy(s_fore)
        end    

    end

    return lik, all_s_up, Neff
end
# Out:
# PF (generic function with 1 method)

# %%
# main
para = [2.09,0.98,2.25,0.65,0.34,3.16,0.51,0.81,0.98,0.93,0.19,0.65,0.24]
T1,T0 = model_solution(para)
A,B,H,R,S2,Phi = sysmat(T1,T0,para)

yt = readdlm("us.txt")

@time liki, measurepredi, statepredi, varstatepredi = KF(A,B,H,R,S2,Phi,yt);
# Out:
# UndefVarError: readdlm not defined
#
# Stacktrace:
#  [1] top-level scope at In[2]:1

# %%
rng = MersenneTwister(1234)
ns = size(B,2)
x0 = zeros(ns)
P0 = nearestSPD(dlyap(Phi,R*S2*R')) # to make it positive semidefinite
N = 40000 # number of particles 

@time lik, all_s_up, Neff = PF(A, B, H, Phi, R, S2, N, yt, x0, P0, 1);
# Out:
#   1.914192 seconds (301.30 k allocations: 1.716 GiB, 14.99% gc time)

# %%
println([sum(liki) sum(lik)])
plot(liki)
plot!(lik)
# Out:
# [-306.207 -305.464]

# %%
T = 80

rA      = para[5]
piA     = para[6]
gammaQ  = para[7]
rstar = gammaQ+piA/4+rA/4    

y1 = [mean(all_s_up[:,5,:],dims=2), statepredi[1:end-1,5]]
y2 = [mean(all_s_up[:,6,:],dims=2), statepredi[1:end-1,6]]
y3 = [mean(all_s_up[:,3,:],dims=2), statepredi[1:end-1,3]] #, [0; yt[1:end-1,3]]/4 .- rstar]
plot(
    plot([1:T],y1,title="g",legend=false),
    plot([1:T],y2,title="z",legend=false),
    plot([1:T],y3,title="R"),
    layout=(3,1),size=(600,350),label=["PF" "KF"] #,legend=false
)
# Out:
# UndefVarError: para not defined
#
# Stacktrace:
#  [1] top-level scope at In[1]:2

# %%
println(N)
plot(Neff,legend=false)
# Out:
# 40000

# %%
liki, measurepredi, statepredi, varstatepredi = KF(A,B,H,R,S2,Phi,yt)

N_opts = [50, 100, 1000]
# N_opts = [40000]

Nrep = 100

lik_store = zeros(Nrep, size(N_opts)[1])

for r = 1:Nrep
    
    for n = 1:size(N_opts)[1]
        
        N = N_opts[n]
        
        @time lik, all_s_up, Neff = PF(A, B, H, Phi, R, S2, N, yt, x0, P0, 1)
        
        lik_store[r,n] = sum(lik) - sum(liki)
        
    end
    
end
# Out:
#   0.002448 seconds (2.27 k allocations: 2.277 MiB)
#   0.003713 seconds (2.59 k allocations: 4.608 MiB)
#   0.043037 seconds (3.39 k allocations: 43.816 MiB, 28.85% gc time)
#   0.001958 seconds (2.27 k allocations: 2.277 MiB)
#   0.009726 seconds (2.59 k allocations: 4.608 MiB, 34.60% gc time)
#   0.041493 seconds (3.39 k allocations: 43.816 MiB, 15.27% gc time)
#   0.001491 seconds (2.27 k allocations: 2.277 MiB)
#   0.003936 seconds (2.59 k allocations: 4.608 MiB)
#   0.038205 seconds (3.39 k allocations: 43.816 MiB, 14.02% gc time)
#   0.002047 seconds (2.27 k allocations: 2.277 MiB)
#   0.003341 seconds (2.59 k allocations: 4.608 MiB)
#   0.039740 seconds (3.39 k allocations: 43.816 MiB, 16.63% gc time)
#   0.002226 seconds (2.27 k allocations: 2.277 MiB)
#   0.004308 seconds (2.59 k allocations: 4.608 MiB)
#   0.040363 seconds (3.39 k allocations: 43.816 MiB, 16.81% gc time)
#   0.001879 seconds (2.27 k allocations: 2.277 MiB)
#   0.007733 seconds (2.59 k allocations: 4.608 MiB, 53.82% gc time)
#   0.036164 seconds (3.39 k allocations: 43.816 MiB, 12.93% gc time)
#   0.001964 seconds (2.27 k allocations: 2.277 MiB)
#   0.003914 seconds (2.59 k allocations: 4.608 MiB)
#   0.040107 seconds (3.39 k allocations: 43.816 MiB, 14.67% gc time)
#   0.001764 seconds (2.27 k allocations: 2.277 MiB)
#   0.003731 seconds (2.59 k allocations: 4.608 MiB)
#   0.035307 seconds (3.39 k allocations: 43.816 MiB, 12.40% gc time)
#   0.001644 seconds (2.27 k allocations: 2.277 MiB)
#   0.004069 seconds (2.59 k allocations: 4.608 MiB, 43.20% gc time)
#   0.034060 seconds (3.39 k allocations: 43.816 MiB, 19.37% gc time)
#   0.001880 seconds (2.27 k allocations: 2.277 MiB)
#   0.003557 seconds (2.59 k allocations: 4.608 MiB)
#   0.032849 seconds (3.39 k allocations: 43.816 MiB, 12.92% gc time)
#   0.001905 seconds (2.27 k allocations: 2.277 MiB)
#   0.003582 seconds (2.59 k allocations: 4.608 MiB)
#   0.027576 seconds (3.39 k allocations: 43.816 MiB, 9.10% gc time)
#   0.001707 seconds (2.27 k allocations: 2.277 MiB)
#   0.002526 seconds (2.59 k allocations: 4.608 MiB)
#   0.033381 seconds (3.39 k allocations: 43.816 MiB, 17.06% gc time)
#   0.001822 seconds (2.27 k allocations: 2.277 MiB)
#   0.006997 seconds (2.59 k allocations: 4.608 MiB, 49.89% gc time)
#   0.032413 seconds (3.39 k allocations: 43.816 MiB, 11.80% gc time)
#   0.001535 seconds (2.27 k allocations: 2.277 MiB)
#   0.003941 seconds (2.59 k allocations: 4.608 MiB)
#   0.038044 seconds (3.39 k allocations: 43.816 MiB, 11.15% gc time)
#   0.001408 seconds (2.27 k allocations: 2.277 MiB)
#   0.002189 seconds (2.59 k allocations: 4.608 MiB)
#   0.029383 seconds (3.39 k allocations: 43.816 MiB, 14.69% gc time)
#   0.002062 seconds (2.27 k allocations: 2.277 MiB)
#   0.005033 seconds (2.59 k allocations: 4.608 MiB, 33.10% gc time)
#   0.037430 seconds (3.39 k allocations: 43.816 MiB, 16.57% gc time)
#   0.001592 seconds (2.27 k allocations: 2.277 MiB)
#   0.003103 seconds (2.59 k allocations: 4.608 MiB)
#   0.029404 seconds (3.39 k allocations: 43.816 MiB, 8.73% gc time)
#   0.001362 seconds (2.27 k allocations: 2.277 MiB)
#   0.002394 seconds (2.59 k allocations: 4.608 MiB)
#   0.022589 seconds (3.39 k allocations: 43.816 MiB, 11.20% gc time)
#   0.001456 seconds (2.27 k allocations: 2.277 MiB)
#   0.002280 seconds (2.59 k allocations: 4.608 MiB)
#   0.038114 seconds (3.39 k allocations: 43.816 MiB, 13.59% gc time)
#   0.001453 seconds (2.27 k allocations: 2.277 MiB)
#   0.004209 seconds (2.59 k allocations: 4.608 MiB, 39.99% gc time)
#   0.021612 seconds (3.39 k allocations: 43.816 MiB, 8.53% gc time)
#   0.001386 seconds (2.27 k allocations: 2.277 MiB)
#   0.002387 seconds (2.59 k allocations: 4.608 MiB)
#   0.027325 seconds (3.39 k allocations: 43.816 MiB, 16.54% gc time)
#   0.002009 seconds (2.27 k allocations: 2.277 MiB)
#   0.003370 seconds (2.59 k allocations: 4.608 MiB)
#   0.027106 seconds (3.39 k allocations: 43.816 MiB, 9.65% gc time)
#   0.001470 seconds (2.27 k allocations: 2.277 MiB)
#   0.005712 seconds (2.59 k allocations: 4.608 MiB, 56.91% gc time)
#   0.038771 seconds (3.39 k allocations: 43.816 MiB, 10.21% gc time)
#   0.001662 seconds (2.27 k allocations: 2.277 MiB)
#   0.002465 seconds (2.59 k allocations: 4.608 MiB)
#   0.034266 seconds (3.39 k allocations: 43.816 MiB, 13.32% gc time)
#   0.001832 seconds (2.27 k allocations: 2.277 MiB)
#   0.002425 seconds (2.59 k allocations: 4.608 MiB)
#   0.032850 seconds (3.39 k allocations: 43.816 MiB, 16.81% gc time)
#   0.002325 seconds (2.27 k allocations: 2.277 MiB)
#   0.003375 seconds (2.59 k allocations: 4.608 MiB)
#   0.025069 seconds (3.39 k allocations: 43.816 MiB, 10.23% gc time)
#   0.001523 seconds (2.27 k allocations: 2.277 MiB)
#   0.003985 seconds (2.59 k allocations: 4.608 MiB, 40.82% gc time)
#   0.027454 seconds (3.39 k allocations: 43.816 MiB, 15.04% gc time)
#   0.001492 seconds (2.27 k allocations: 2.277 MiB)
#   0.003516 seconds (2.59 k allocations: 4.608 MiB)
#   0.027147 seconds (3.39 k allocations: 43.816 MiB, 8.79% gc time)
#   0.001449 seconds (2.27 k allocations: 2.277 MiB)
#   0.002684 seconds (2.59 k allocations: 4.608 MiB)
#   0.025332 seconds (3.39 k allocations: 43.816 MiB, 10.52% gc time)
#   0.001709 seconds (2.27 k allocations: 2.277 MiB)
#   0.003964 seconds (2.59 k allocations: 4.608 MiB, 40.82% gc time)
#   0.034222 seconds (3.39 k allocations: 43.816 MiB, 11.92% gc time)
#   0.001372 seconds (2.27 k allocations: 2.277 MiB)
#   0.002697 seconds (2.59 k allocations: 4.608 MiB)
#   0.022990 seconds (3.39 k allocations: 43.816 MiB, 11.12% gc time)
#   0.001727 seconds (2.27 k allocations: 2.277 MiB)
#   0.002528 seconds (2.59 k allocations: 4.608 MiB)
#   0.024407 seconds (3.39 k allocations: 43.816 MiB, 10.65% gc time)
#   0.001391 seconds (2.27 k allocations: 2.277 MiB)
#   0.002288 seconds (2.59 k allocations: 4.608 MiB)
#   0.035413 seconds (3.39 k allocations: 43.816 MiB, 14.11% gc time)
#   0.001604 seconds (2.27 k allocations: 2.277 MiB)
#   0.004494 seconds (2.59 k allocations: 4.608 MiB, 38.32% gc time)
#   0.023954 seconds (3.39 k allocations: 43.816 MiB, 8.28% gc time)
#   0.001495 seconds (2.27 k allocations: 2.277 MiB)
#   0.002201 seconds (2.59 k allocations: 4.608 MiB)
#   0.024495 seconds (3.39 k allocations: 43.816 MiB, 10.57% gc time)
#   0.001502 seconds (2.27 k allocations: 2.277 MiB)
#   0.002337 seconds (2.59 k allocations: 4.608 MiB)
#   0.025936 seconds (3.39 k allocations: 43.816 MiB, 10.82% gc time)
#   0.001716 seconds (2.27 k allocations: 2.277 MiB)
#   0.004221 seconds (2.59 k allocations: 4.608 MiB, 38.23% gc time)
#   0.027851 seconds (3.39 k allocations: 43.816 MiB, 17.09% gc time)
#   0.001910 seconds (2.27 k allocations: 2.277 MiB)
#   0.004007 seconds (2.59 k allocations: 4.608 MiB)
#   0.030431 seconds (3.39 k allocations: 43.816 MiB, 8.08% gc time)
#   0.001546 seconds (2.27 k allocations: 2.277 MiB)
#   0.002659 seconds (2.59 k allocations: 4.608 MiB)
#   0.024114 seconds (3.39 k allocations: 43.816 MiB, 11.10% gc time)
#   0.001359 seconds (2.27 k allocations: 2.277 MiB)
#   0.002520 seconds (2.59 k allocations: 4.608 MiB)
#   0.029164 seconds (3.39 k allocations: 43.816 MiB, 15.02% gc time)
#   0.001777 seconds (2.27 k allocations: 2.277 MiB)
#   0.005131 seconds (2.59 k allocations: 4.608 MiB, 34.18% gc time)
#   0.024001 seconds (3.39 k allocations: 43.816 MiB, 8.77% gc time)
#   0.001377 seconds (2.27 k allocations: 2.277 MiB)
#   0.002373 seconds (2.59 k allocations: 4.608 MiB)
#   0.024881 seconds (3.39 k allocations: 43.816 MiB, 10.53% gc time)
#   0.001761 seconds (2.27 k allocations: 2.277 MiB)
#   0.002770 seconds (2.59 k allocations: 4.608 MiB)
#   0.036906 seconds (3.39 k allocations: 43.816 MiB, 13.60% gc time)
#   0.001452 seconds (2.27 k allocations: 2.277 MiB)
#   0.004821 seconds (2.59 k allocations: 4.608 MiB, 46.43% gc time)
#   0.023734 seconds (3.39 k allocations: 43.816 MiB, 8.10% gc time)
#   0.001348 seconds (2.27 k allocations: 2.277 MiB)
#   0.002567 seconds (2.59 k allocations: 4.608 MiB)
#   0.035575 seconds (3.39 k allocations: 43.816 MiB, 14.00% gc time)
#   0.001557 seconds (2.27 k allocations: 2.277 MiB)
#   0.002371 seconds (2.59 k allocations: 4.608 MiB)
#   0.024364 seconds (3.39 k allocations: 43.816 MiB, 10.53% gc time)
#   0.001605 seconds (2.27 k allocations: 2.277 MiB)
#   0.002570 seconds (2.59 k allocations: 4.608 MiB)
#   0.025557 seconds (3.39 k allocations: 43.816 MiB, 10.94% gc time)
#   0.001621 seconds (2.27 k allocations: 2.277 MiB)
#   0.003940 seconds (2.59 k allocations: 4.608 MiB, 41.36% gc time)
#   0.029542 seconds (3.39 k allocations: 43.816 MiB, 6.47% gc time)
#   0.001422 seconds (2.27 k allocations: 2.277 MiB)
#   0.002114 seconds (2.59 k allocations: 4.608 MiB)
#   0.023107 seconds (3.39 k allocations: 43.816 MiB, 12.48% gc time)
#   0.001440 seconds (2.27 k allocations: 2.277 MiB)
#   0.002278 seconds (2.59 k allocations: 4.608 MiB)
#   0.021166 seconds (3.39 k allocations: 43.816 MiB, 12.34% gc time)
#   0.001395 seconds (2.27 k allocations: 2.277 MiB)
#   0.004021 seconds (2.59 k allocations: 4.608 MiB, 38.75% gc time)
#   0.023680 seconds (3.39 k allocations: 43.816 MiB, 7.92% gc time)
#   0.001388 seconds (2.27 k allocations: 2.277 MiB)
#   0.002729 seconds (2.59 k allocations: 4.608 MiB)
#   0.026774 seconds (3.39 k allocations: 43.816 MiB, 16.20% gc time)
#   0.001911 seconds (2.27 k allocations: 2.277 MiB)
#   0.003745 seconds (2.59 k allocations: 4.608 MiB)
#   0.027642 seconds (3.39 k allocations: 43.816 MiB, 9.88% gc time)
#   0.001567 seconds (2.27 k allocations: 2.277 MiB)
#   0.002887 seconds (2.59 k allocations: 4.608 MiB)
#   0.024167 seconds (3.39 k allocations: 43.816 MiB, 11.62% gc time)
#   0.001339 seconds (2.27 k allocations: 2.277 MiB)
#   0.004244 seconds (2.59 k allocations: 4.608 MiB, 40.40% gc time)
#   0.034395 seconds (3.39 k allocations: 43.816 MiB, 12.02% gc time)
#   0.001893 seconds (2.27 k allocations: 2.277 MiB)
#   0.002587 seconds (2.59 k allocations: 4.608 MiB)
#   0.024461 seconds (3.39 k allocations: 43.816 MiB, 11.25% gc time)
#   0.001396 seconds (2.27 k allocations: 2.277 MiB)
#   0.002579 seconds (2.59 k allocations: 4.608 MiB)
#   0.025970 seconds (3.39 k allocations: 43.816 MiB, 10.57% gc time)
#   0.001769 seconds (2.27 k allocations: 2.277 MiB)
#   0.003905 seconds (2.59 k allocations: 4.608 MiB, 42.05% gc time)
#   0.023665 seconds (3.39 k allocations: 43.816 MiB, 7.63% gc time)
#   0.001433 seconds (2.27 k allocations: 2.277 MiB)
#   0.002946 seconds (2.59 k allocations: 4.608 MiB)
#   0.025079 seconds (3.39 k allocations: 43.816 MiB, 10.26% gc time)
#   0.001570 seconds (2.27 k allocations: 2.277 MiB)
#   0.002396 seconds (2.59 k allocations: 4.608 MiB)
#   0.024211 seconds (3.39 k allocations: 43.816 MiB, 11.87% gc time)
#   0.001350 seconds (2.27 k allocations: 2.277 MiB)
#   0.003033 seconds (2.59 k allocations: 4.608 MiB)
#   0.023926 seconds (3.39 k allocations: 43.816 MiB, 11.00% gc time)
#   0.001599 seconds (2.27 k allocations: 2.277 MiB)
#   0.003859 seconds (2.59 k allocations: 4.608 MiB, 41.00% gc time)
#   0.025636 seconds (3.39 k allocations: 43.816 MiB, 15.78% gc time)
#   0.001607 seconds (2.27 k allocations: 2.277 MiB)
#   0.003929 seconds (2.59 k allocations: 4.608 MiB)
#   0.030879 seconds (3.39 k allocations: 43.816 MiB, 8.26% gc time)
#   0.001401 seconds (2.27 k allocations: 2.277 MiB)
#   0.002650 seconds (2.59 k allocations: 4.608 MiB)
#   0.024566 seconds (3.39 k allocations: 43.816 MiB, 11.19% gc time)
#   0.001526 seconds (2.27 k allocations: 2.277 MiB)
#   0.004171 seconds (2.59 k allocations: 4.608 MiB, 40.74% gc time)
#   0.027763 seconds (3.39 k allocations: 43.816 MiB, 7.83% gc time)
#   0.001626 seconds (2.27 k allocations: 2.277 MiB)
#   0.002613 seconds (2.59 k allocations: 4.608 MiB)
#   0.027036 seconds (3.39 k allocations: 43.816 MiB, 10.56% gc time)
#   0.001564 seconds (2.27 k allocations: 2.277 MiB)
#   0.003248 seconds (2.59 k allocations: 4.608 MiB)
#   0.033818 seconds (3.39 k allocations: 43.816 MiB, 14.35% gc time)
#   0.001919 seconds (2.27 k allocations: 2.277 MiB)
#   0.004482 seconds (2.59 k allocations: 4.608 MiB)
#   0.025960 seconds (3.39 k allocations: 43.816 MiB, 11.19% gc time)
#   0.001455 seconds (2.27 k allocations: 2.277 MiB)
#   0.004087 seconds (2.59 k allocations: 4.608 MiB, 39.79% gc time)
#   0.021866 seconds (3.39 k allocations: 43.816 MiB, 8.65% gc time)
#   0.001681 seconds (2.27 k allocations: 2.277 MiB)
#   0.002475 seconds (2.59 k allocations: 4.608 MiB)
#   0.023307 seconds (3.39 k allocations: 43.816 MiB, 10.72% gc time)
#   0.001556 seconds (2.27 k allocations: 2.277 MiB)
#   0.002147 seconds (2.59 k allocations: 4.608 MiB)
#   0.035727 seconds (3.39 k allocations: 43.816 MiB, 14.04% gc time)
#   0.001770 seconds (2.27 k allocations: 2.277 MiB)
#   0.004397 seconds (2.59 k allocations: 4.608 MiB, 41.13% gc time)
#   0.027148 seconds (3.39 k allocations: 43.816 MiB, 7.44% gc time)
#   0.001462 seconds (2.27 k allocations: 2.277 MiB)
#   0.003331 seconds (2.59 k allocations: 4.608 MiB)
#   0.024108 seconds (3.39 k allocations: 43.816 MiB, 11.50% gc time)
#   0.001930 seconds (2.27 k allocations: 2.277 MiB)
#   0.002938 seconds (2.59 k allocations: 4.608 MiB)
#   0.026291 seconds (3.39 k allocations: 43.816 MiB, 11.23% gc time)
#   0.001467 seconds (2.27 k allocations: 2.277 MiB)
#   0.002568 seconds (2.59 k allocations: 4.608 MiB)
#   0.023896 seconds (3.39 k allocations: 43.816 MiB, 10.71% gc time)
#   0.001498 seconds (2.27 k allocations: 2.277 MiB)
#   0.004002 seconds (2.59 k allocations: 4.608 MiB, 39.87% gc time)
#   0.021900 seconds (3.39 k allocations: 43.816 MiB, 8.15% gc time)
#   0.001359 seconds (2.27 k allocations: 2.277 MiB)
#   0.002300 seconds (2.59 k allocations: 4.608 MiB)
#   0.028340 seconds (3.39 k allocations: 43.816 MiB, 17.97% gc time)
#   0.001699 seconds (2.27 k allocations: 2.277 MiB)
#   0.003165 seconds (2.59 k allocations: 4.608 MiB)
#   0.030611 seconds (3.39 k allocations: 43.816 MiB, 10.21% gc time)
#   0.001515 seconds (2.27 k allocations: 2.277 MiB)
#   0.004287 seconds (2.59 k allocations: 4.608 MiB, 38.78% gc time)
#   0.024104 seconds (3.39 k allocations: 43.816 MiB, 8.01% gc time)
#   0.001660 seconds (2.27 k allocations: 2.277 MiB)
#   0.002476 seconds (2.59 k allocations: 4.608 MiB)
#   0.024048 seconds (3.39 k allocations: 43.816 MiB, 10.51% gc time)
#   0.001668 seconds (2.27 k allocations: 2.277 MiB)
#   0.002416 seconds (2.59 k allocations: 4.608 MiB)
#   0.024215 seconds (3.39 k allocations: 43.816 MiB, 11.26% gc time)
#   0.001407 seconds (2.27 k allocations: 2.277 MiB)
#   0.002591 seconds (2.59 k allocations: 4.608 MiB)
#   0.032238 seconds (3.39 k allocations: 43.816 MiB, 14.86% gc time)
#   0.002050 seconds (2.27 k allocations: 2.277 MiB)
#   0.004662 seconds (2.59 k allocations: 4.608 MiB, 35.32% gc time)
#   0.026265 seconds (3.39 k allocations: 43.816 MiB, 8.56% gc time)
#   0.001604 seconds (2.27 k allocations: 2.277 MiB)
#   0.002312 seconds (2.59 k allocations: 4.608 MiB)
#   0.025244 seconds (3.39 k allocations: 43.816 MiB, 10.51% gc time)
#   0.001808 seconds (2.27 k allocations: 2.277 MiB)
#   0.002285 seconds (2.59 k allocations: 4.608 MiB)
#   0.032365 seconds (3.39 k allocations: 43.816 MiB, 13.61% gc time)
#   0.001396 seconds (2.27 k allocations: 2.277 MiB)
#   0.003864 seconds (2.59 k allocations: 4.608 MiB, 41.34% gc time)
#   0.026225 seconds (3.39 k allocations: 43.816 MiB, 7.95% gc time)
#   0.001608 seconds (2.27 k allocations: 2.277 MiB)
#   0.002379 seconds (2.59 k allocations: 4.608 MiB)
#   0.029518 seconds (3.39 k allocations: 43.816 MiB, 17.15% gc time)
#   0.002338 seconds (2.27 k allocations: 2.277 MiB)
#   0.003835 seconds (2.59 k allocations: 4.608 MiB)
#   0.031184 seconds (3.39 k allocations: 43.816 MiB, 8.76% gc time)
#   0.002090 seconds (2.27 k allocations: 2.277 MiB)
#   0.002446 seconds (2.59 k allocations: 4.608 MiB)
#   0.026327 seconds (3.39 k allocations: 43.816 MiB, 13.36% gc time)
#   0.001662 seconds (2.27 k allocations: 2.277 MiB)
#   0.006461 seconds (2.59 k allocations: 4.608 MiB, 58.73% gc time)
#   0.033314 seconds (3.39 k allocations: 43.816 MiB, 8.26% gc time)
#   0.001395 seconds (2.27 k allocations: 2.277 MiB)
#   0.002849 seconds (2.59 k allocations: 4.608 MiB)
#   0.024100 seconds (3.39 k allocations: 43.816 MiB, 10.46% gc time)
#   0.001398 seconds (2.27 k allocations: 2.277 MiB)
#   0.003186 seconds (2.59 k allocations: 4.608 MiB)
#   0.033601 seconds (3.39 k allocations: 43.816 MiB, 15.46% gc time)
#   0.002274 seconds (2.27 k allocations: 2.277 MiB)
#   0.004963 seconds (2.59 k allocations: 4.608 MiB, 31.62% gc time)
#   0.026554 seconds (3.39 k allocations: 43.816 MiB, 7.44% gc time)
#   0.001385 seconds (2.27 k allocations: 2.277 MiB)
#   0.002563 seconds (2.59 k allocations: 4.608 MiB)
#   0.024626 seconds (3.39 k allocations: 43.816 MiB, 11.78% gc time)
#   0.002162 seconds (2.27 k allocations: 2.277 MiB)
#   0.002998 seconds (2.59 k allocations: 4.608 MiB)
#   0.024093 seconds (3.39 k allocations: 43.816 MiB, 10.53% gc time)
#   0.001442 seconds (2.27 k allocations: 2.277 MiB)
#   0.002579 seconds (2.59 k allocations: 4.608 MiB)
#   0.023827 seconds (3.39 k allocations: 43.816 MiB, 11.46% gc time)
#   0.001745 seconds (2.27 k allocations: 2.277 MiB)
#   0.004037 seconds (2.59 k allocations: 4.608 MiB, 39.87% gc time)
#   0.023337 seconds (3.39 k allocations: 43.816 MiB, 7.57% gc time)
#   0.001293 seconds (2.27 k allocations: 2.277 MiB)
#   0.002308 seconds (2.59 k allocations: 4.608 MiB)
#   0.022669 seconds (3.39 k allocations: 43.816 MiB, 11.43% gc time)
#   0.001797 seconds (2.27 k allocations: 2.277 MiB)
#   0.002631 seconds (2.59 k allocations: 4.608 MiB)
#   0.022953 seconds (3.39 k allocations: 43.816 MiB, 11.09% gc time)
#   0.001701 seconds (2.27 k allocations: 2.277 MiB)
#   0.006531 seconds (2.59 k allocations: 4.608 MiB, 63.92% gc time)
#   0.030294 seconds (3.39 k allocations: 43.816 MiB, 6.06% gc time)

# %%
m = mean(lik_store,dims=1)
v = std(lik_store,dims=1)
for i = 1:3
    println([Nrep N_opts[i] m[i]+sum(liki) v[i]])
end
# Out:
# [100.0 50.0 -527.273 44.3926]
# [100.0 100.0 -439.843 37.8824]
# [100.0 1000.0 -335.226 12.1541]

# %%
kd1 = kde(lik_store[:,1])
kd2 = kde(lik_store[:,2])
kd3 = kde(lik_store[:,3])

plot(kd1.x,kd1.density,linestyle=:dash,linewidth=3,label="N=50")
plot!(kd2.x,kd2.density,linewidth=3,label="N=100")
plot!(kd3.x,kd3.density,linestyle=:dot,linewidth=3,label="N=1000",legend=:topleft)
